# %% [markdown]
# ## Setup

# %%
# Import the userdata module from Google Colab
from google.colab import userdata

# Retrieve OpenAI API key
api_key = userdata.get('openai_api')

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change directory to project folder
# %cd /content/drive/MyDrive/RAG\ Course
# Out:
# /content/drive/MyDrive/RAG Course

# %% [markdown]
# ## Install Libraries

# %%
# Install the pdf2image library for converting PDF files to images
# !pip install pdf2image

# Install the poppler-utils package, required by pdf2image to work with PDF files
# !apt-get install poppler-utils

# Install the openAI library
# !pip install openai
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pdf2image) (11.3.0)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.10 [186 kB]
# Fetched 186 kB in 1s (235 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126371 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.10_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.10) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.10) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.100.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %% [markdown]
# ## Import Libraries

# %%
from pdf2image import convert_from_path
from IPython.display import Markdown, display
from openai import OpenAI
import base64
import os
import json

# %% [markdown]
# ## Perform OCR and Transform To Images

# %%
# Function to convert PDFs into images and stores the image paths
def pdf_to_images(pdf_path, output_folder):
  # Create the output folder if it doesn't exist
  if not os.path.exists(output_folder):
    os.makedirs(output_folder)

  # Convert PDF into images
  images = convert_from_path(pdf_path)

  # Save images and store their paths
  image_paths = []

  for i, image in enumerate(images):
    image_path = os.path.join(output_folder, f"page{i+1}.jpg") # Generate the image file path
    image.save(image_path, "JPEG") # Save the image as a JPEG file
    image_paths.append(image_path) # Append the image path to the list

  return image_paths # Return the list of image paths

# %%
# Define the path to the PDF and the output folder for images
pdf_path = "recipe_book.pdf"
output_folder = "images"

# Convert the PDF into images and store the image paths
image_paths = pdf_to_images(pdf_path, output_folder)

# %% [markdown]
# ## Set Up OpenAI and The Model We Are Using

# %%
client = OpenAI(api_key=api_key)
model = "gpt-4o-mini"

# %% [markdown]
# ### Test how things work on one image - Extract recipe info

# %%
# Read and encode one image
image_path = "images/page23.jpg" # Path to the image to be encoded

# Encode the image in base64 and decode to string
with open(image_path, "rb") as image_file:
  image_data = base64.b64encode(image_file.read()).decode('utf-8')
image_data
# Out:
# '...'

# %%
# Extract the recipe from the image

# Define the system prompt
system_prompt = """
Please analyze the content of this image and extract any related recipe information.
"""

# Call the OpenAI API use the chat completion method
response = client.chat.completions.create(
    model = model,
    messages = [
        # Provide the system prompt
        {"role": "system", "content": system_prompt},

        # The user message contains both the text and image URL / path
        {"role": "user", "content": [
            "This is the image from the recipe page.",
            {"type": "image_url",
             "image_url": {"url": f"data:image/jpeg;base64,{image_data}",
                           "detail": "low"}}
        ]}
    ]
)

# Retrieve the content
gpt_response = response.choices[0].message.content

# Display the GPT response as Markdown
display(Markdown(gpt_response))
# Out:
# Based on the content of the image you provided, here are two recipes:
#
# ### Bannocks
# **Ingredients:**
# - 1 Cupful of Thick Sour Milk
# - ½ Cupful of Sugar
# - 1 Cupful of Flour
# - ½ Cupful of Indian Meal
# - 1 Teaspoonful of Soda
# - A pinch of Salt
#
# **Instructions:**
# 1. Make the mixture and drop from a spoon.
# 2. Drop mixture, size of a walnut, into boiling fat.
# 3. Serve warm with maple syrup.
#
# ### Boston Brown Bread
# **Ingredients:**
# - 1 Cupful of Rye Meal
# - 1 Cupful of Sour Milk
# - 1 Cupful of Graham Meal
# - 1 Cupful of Molasses
# - 1 Cupful of Flour
# - ½ Teaspoonful of Salt
# - 1 Heaping Teaspoonful of Soda
# - 1 Cupful of Sweet Milk
#
# **Instructions:**
# 1. Stir the meals and salt together.
# 2. Beat the soda into the molasses until it foams; add sour milk, mix thoroughly, and pour into a tin with a lid.
# 3. Steam for three hours; then pour into a pan.
#
# Feel free to ask if you need any more assistance!

# %% [markdown]
# ## Let's Continue On All the Data - Extract all recipe information

# %%
# Define improved system prompt
system_prompt = """
Please analyze the content of this image and extract any related recipe information into structure components.
Specifically, extract the recipe title, list of ingredients, step by step instructions, cuisine type, dish type, any relevant tags or metadata.
The output must be formatted in a way suited for embedding in a Retrieval Augmented Generation (RAG) system.
"""

# %%
# Extract information about all of the images/recipes
extracted_recipes = []

for image_path in image_paths:
  print(f"Processing image {image_path}")

  # Reading and decoding the image
  with open(image_path, "rb") as image_file:
    image_data = base64.b64encode(image_file.read()).decode("utf-8") # Encode the image to base64 format

  # Call the API to extract the information
  response = client.chat.completions.create(
      model = model,
      messages = [
          # Provide system prompt for guidance
          {"role": "system", "content": system_prompt},

          # The user message contains both the text and image URL / path
          {"role": "user", "content": [
              "This is the image from the recipe page", # Context for the image
              {"type": "image_url",
              "image_url": {"url": f"data:image/jpeg;base64,{image_data}", # Provide the base64 image
                            "detail": "low"}}
          ]}
      ],
      temperature = 0, # Set the temperature to 0 for deterministic output
  )

  # Extract the content and store it
  gpt_response = response.choices[0].message.content # Get the response content
  extracted_recipes.append({"image_path": image_path, "recipe_info": gpt_response}) # Store the path and extracted info
  print(f"Extracted information for {image_path}:\n{gpt_response}\n") # Print the extracted information for review
# Out:
# Streaming output truncated to the last 5000 lines.
# 1. Stir the soda into the molasses until it foams.
# 2. Add sour milk, ginger, salt, and melted butter.
# 3. Last, add flour enough for quite a stiff batter, and bake. This makes one sheet.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags
# - Gingerbread
# - Baking
# - Traditional Recipes
#
# ---
#
# ### Recipe Title
# Huckleberry Cake
#
# ### Ingredients
# - 1 Cup of Fresh Huckleberries
# - 1 Pint of Graham Meal
# - 1 Cup of Sour Milk
# - 1 Teaspoon of Soda
# - ½ Teaspoon of Salt
# - Butter (for serving)
#
# ### Instructions
# 1. Pick over and wash and flour one cupful of fresh huckleberries.
# 2. Add these to the batter and stir together.
# 3. Serve hot with butter.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags
# - Huckleberry
# - Cake
# - Baking
# - Traditional Recipes
#
# ---
#
# ### Recipe Title
# Quick Graham Bread
#
# ### Ingredients
# - 1 Pint of Graham Meal
# - 1 Cup of Sour Milk
# - 1 Teaspoon of Soda
# - ½ Teaspoon of Salt
# - Butter (for serving)
#
# ### Instructions
# 1. Stir into the molasses, add sour milk and salt; add to the meal.
# 2. Sweet milk will do with a little less soda.
# 3. Bake thirty minutes, or according to heat of the oven. A moderate oven is best.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread
#
# ### Relevant Tags
# - Graham Bread
# - Baking
# - Traditional Recipes
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page28.jpg
# Extracted information for images/page28.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Graham Bread (raised over night)
#
# ### Ingredients
# - 3 Cupfuls of Graham Flour
# - 1 Tablespoonful of Lard
# - ½ Teaspoonful of Salt
# - 1 Meal
# - 2 Tablespoonfuls of Sugar
# - 1 Cupful of Water
# - 1 Package of Yeast
#
# ### Instructions
# 1. Mix flour and meal together and rub in lard, salt, and sugar.
# 2. Add yeast cake which has been dissolved in one-half cup of cold water. Mix with warm water at night.
# 3. Set in a warm place to rise. In the morning stir and let rise twice its bulk. Knead and put in baking pans. Let stand bake forty-five minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread
#
# ### Relevant Tags
# - Yeast Bread
# - Breakfast
# - Homemade
#
# ---
#
# ### Additional Recipe
# #### Recipe Title
# Graham Muffins
#
# ### Ingredients
# - 1 Pint of Whole Milk
# - ½ Cupful of Molasses
# - 1 Teaspoonful of Salt
# - 2 Cupfuls of Graham Flour
#
# ### Instructions
# 1. Put the milk and molasses into a bowl and mix with salt.
# 2. Stir in the Graham flour and mix until combined.
# 3. Drop into muffin tins and bake twenty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Muffins
#
# ### Relevant Tags
# - Muffins
# - Breakfast
# - Homemade
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page29.jpg
# Extracted information for images/page29.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Sweet Milk Griddle Cakes
#
# ### Ingredients
# - 1 Egg
# - 1 Pint of Sweet Milk
# - 2 Level Teaspoons of Cream of Tartar
# - 1 Level Teaspoon of Salt
# - Flour enough for thin batter
# - Butter (for cooking)
# - Maple syrup (for serving)
#
# ### Instructions
# 1. Beat the egg and milk together.
# 2. Add the cream of tartar and salt.
# 3. Stir in the flour until a thin batter is formed.
# 4. Fry in hot butter on a griddle.
# 5. Serve hot with butter and maple syrup.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Breakfast
#
# ### Tags/Metadata
# - Griddle Cakes
# - Breakfast Recipe
# - Sweet Recipe
#
# ---
#
# ### Recipe Title
# Jenny Lind Tea Cake
#
# ### Ingredients
# - 1 Egg
# - ½ Cupful of Sugar
# - 1 Tablespoon of Melted Butter
# - Flour (enough to make a batter)
# - 1 Teaspoon of Salt
# - 1 Teaspoon of Cream of Tartar
#
# ### Instructions
# 1. Stir salt, egg, and sugar into the dry flour.
# 2. Add melted butter and enough milk to make a batter thick as cake.
# 3. Bake in a moderate oven.
# 4. Serve warm.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Tags/Metadata
# - Tea Cake
# - Dessert Recipe
# - Sweet Recipe
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page30.jpg
# Extracted information for images/page30.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Real Johnny Cake
#
# ### Ingredients
# - 2 Cups of Flour
# - 1 Cupful of Yeast
# - 1 Cupful of Sugar
# - ½ Teaspoon of Salt
# - 1 Teaspoon of Cream of Tartar
# - ½ Teaspoon of Baking Powder
# - Enough milk or water to make a thin batter
#
# ### Step-by-Step Instructions
# 1. Dissolve the yeast in a half-cup of cold water.
# 2. Scale the milk and water, and mix with the flour and sugar.
# 3. Let the mixture rise to twice its volume.
# 4. When light and frothy, add the rest of the ingredients.
# 5. Mix in a little flour, using a cookie cutter to cut out the dough.
# 6. Let rise again.
# 7. Bake in a moderate oven.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Baked Good
#
# ### Relevant Tags/Metadata
# - Baking
# - Yeast Bread
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page31.jpg
# Extracted information for images/page31.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Nut Bread
#
# ### Ingredients
# - 2½ Cups of Flour
# - 3 Teaspoons of Baking Powder
# - ¾ Cup of Walnuts (or nut meats), chopped
# - ½ Cup of Sugar
# - 2¾ Cups of Rolled Oats
# - 1½ Cups of Molasses
# - 1 Yeast Cake
# - Water
#
# ### Instructions
# 1. Mix the flour, baking powder, and sugar together.
# 2. Add the chopped walnuts.
# 3. Stir in the rolled oats and molasses.
# 4. Dissolve the yeast cake in warm water and add to the mixture.
# 5. Mix well and let it rise for about one hour.
# 6. After rising, stir the mixture again.
# 7. Pour into greased loaf pans and let rise again.
# 8. Bake in a moderate oven until done.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread
#
# ### Tags/Metadata
# - Baking
# - Quick Bread
# - Nut Bread
# - Oatmeal Bread
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page32.jpg
# Extracted information for images/page32.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Parker House Rolls
#
# ### Ingredients
# - 1 Quart of Flour
# - 1 Tablespoon of Salt
# - ½ Pint of Milk
# - 3 Tablespoonfuls of Sugar
# - 1 Yeast Cake
#
# ### Instructions
# 1. Scald the milk, which has been dissolved in one-half cup of cold water.
# 2. Rub the flour, salt, and sugar together in a bowl.
# 3. Stir in the yeast and knead.
# 4. Let rise to twice its bulk and knead again.
# 5. Roll half an inch thick, cut into rounds, and spread with butter and double over.
# 6. Rise again, and bake twenty minutes in a hot oven at ten o'clock in the morning if wanted for supper.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread/Rolls
#
# ### Relevant Tags
# - Yeast Bread
# - Baking
# - Comfort Food
#
# ---
#
# ### Recipe Title
# Popovers
#
# ### Ingredients
# - 1 Egg
# - 1 Cupful of Milk
#
# ### Instructions
# 1. Beat the egg and stir in the milk slowly, a little at a time.
# 2. Salt it lightly.
# 3. This will make a very thin batter.
# 4. Drop into well-buttered muffin pan, bake in a very hot oven and serve with hot sauce for a pudding, or eat with butter.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread/Pastry
#
# ### Relevant Tags
# - Quick Bread
# - Baking
# - Breakfast
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page33.jpg
# Extracted information for images/page33.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Rye Muffins
#
# ### Ingredients
# - 2 Cups of Flour
# - 1 Cupful of Rye Meal
# - 3 Tablespoons of Yeast Cake dissolved in Water
#
# ### Instructions
# 1. Mix with warm water at night.
# 2. In the morning, add one-quarter teaspoonful of soda, dissolved in two tablespoons of boiling water; stir well.
# 3. Bake in a greased pan for twenty or thirty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Muffins
#
# ### Relevant Tags
# - Breakfast
# - Baked Goods
# - Quick Bread
#
# ---
#
# ### Recipe Title
# Breakfast Sally Lunn
#
# ### Ingredients
# - 1 Egg
# - 2 Teacupfuls of Milk
# - 1 Piece of Butter the size of an Egg
# - 4 Tablespoonfuls of Sugar
# - 1 Teaspoonful of Soda
# - 1 Teaspoonful of Cream of Tartar
#
# ### Instructions
# 1. Mix sugar, egg, and soda with the milk.
# 2. Beat the egg, stir into the melted butter and milk.
# 3. Stir all together and bake in a muffin pan, fifteen or twenty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Breakfast Dish
#
# ### Relevant Tags
# - Breakfast
# - Baked Goods
# - Quick Bread
#
# ---
#
# ### Recipe Title
# Sour Milk Biscuits
#
# ### Ingredients
# - 1 Cupful of Sour Milk
# - 1 Teaspoonful of Salt
# - 1 Cupful of Sour Milk
# - 1 Teaspoonful of Soda
#
# ### Instructions
# 1. Put salt and soda into the flour and sour milk.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Biscuits
#
# ### Relevant Tags
# - Breakfast
# - Baked Goods
# - Quick Bread
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page34.jpg
# Extracted information for images/page34.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Spider Cake
#
# ### Ingredients:
# - 2 Cups of Bread Flour
# - 1 Teaspoon of Soda
# - 1/3 Cup of Lard
# - 2 Teaspoons of Cream of Tartar
# - Salt (to taste)
#
# ### Instructions:
# 1. Combine the flour, salt, and cream of tartar in a bowl.
# 2. Rub in the lard until the mixture resembles a soft dough.
# 3. Roll the dough thin and cut into the shape of a spider or use a spider mold.
# 4. Bake on a griddle until golden brown.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Baking
# - Cake
# - Traditional Recipe
#
# Feel free to ask if you need more information!
#
# Processing image images/page35.jpg
# Extracted information for images/page35.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Cakes - Filled Cookies and Sugar Cookies
#
# ### Ingredients
#
# #### Filled Cookies
# - 1 Cupful of Sugar
# - 1 Teaspoonful of Cream of Tartar
# - 1 Cupful of Butter or Lard
# - 1 Cupful of Milk
# - 3½ Cupfuls of Flour
# - 1 Tablespoonful of Vanilla
# - Filling:
#   - ½ Cupful of Chopped Raisins
#   - ½ Cupful of Water
#   - ½ Teaspoonful of Flour
#
# #### Sugar Cookies
# - 1 Cupful of Sugar
# - 2 Teaspoons of Cream of Tartar
# - 2 Tablespoons of Milk
# - 1 Teaspoonful of Soda
# - 1 Egg
# - Flavor enough to roll
#
# ### Step-by-Step Instructions
# 1. For the filled cookies, mix the sugar and butter (or lard) together.
# 2. Add the milk and vanilla, then gradually incorporate the flour and cream of tartar.
# 3. Prepare the filling by cooking the raisins with water and flour until thickened.
# 4. Roll out the cookie dough and place a teaspoon of filling on half of the cookies.
# 5. Cover with the other half and bake until golden brown.
# 6. For sugar cookies, combine sugar, cream of tartar, and butter.
# 7. Add milk, soda, and egg, mixing well.
# 8. Roll out the dough and cut into desired shapes before baking.
#
# ### Cuisine Type
# Baking / Dessert
#
# ### Dish Type
# Cookies
#
# ### Relevant Tags
# - Cookies
# - Baking
# - Dessert
# - Sweet Treats
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page36.jpg
# Extracted information for images/page36.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Cream Cake
#
# ### Ingredients
# - 2 Cups of Flour
# - 1 Cup of Cream of Tartar
# - 1 Teaspoon of Soda
# - 1 Cup of Sugar
# - 1 Cup of Butter
# - 2 Cups of Flour (listed again, possibly a mistake)
# - 1 Cup of Thick Sour Cream
# - 1 Pinch of Salt
# - 1 Teaspoon of Vanilla
# - 1/2 Teaspoon of Cinnamon
# - 1/2 Teaspoon of Cloves
# - Raisins (amount not specified)
# - 3 Eggs
# - 1/2 Cup of Almonds (for Feather Cake)
#
# ### Step-by-Step Instructions
# 1. Stir the cream of tartar and soda into the flour dry. Stir all together and roll.
# 2. In a separate bowl, beat the eggs and add sugar, salt, flour, and cream; last, add the flavoring.
# 3. For the Delicious Cake without Raisins, stir the soda into the sour milk, add melted butter, and sugar, and spices. Pour the flour over the raisins and stir lightly.
# 4. For the Feather Cake, mix the ingredients as specified and beat until smooth.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Cake
#
# ### Relevant Tags or Metadata
# - Baking
# - Dessert
# - Cream Cake
# - Traditional Recipe
#
# This format should be suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page37.jpg
# Extracted information for images/page37.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Old-time Gingersnaps
#
# ### Ingredients
# - ½ Cupful of Molasses
# - ½ Cupful of Butter or Lard
# - 1 Teaspoonful of Soda
# - 1 Teaspoonful of Ginger
# - 1 Teaspoonful of Cinnamon
# - 1 Cupful of Sugar
# - 1 Egg
#
# ### Step-by-Step Instructions
# 1. Boil the molasses for five minutes.
# 2. Remove from heat and add soda, butter, and ginger.
# 3. When cooled a little, roll this into a paste.
# 4. Roll into a tin and bake carefully not to burn.
# 5. Store in a tin for later use.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Cookies
#
# ### Relevant Tags/Metadata
# - Baking
# - Cookies
# - Traditional Recipes
# - Gingersnaps
#
# ---
#
# ### Recipe Title
# Gold Cake
#
# ### Ingredients
# - 1 Cupful of Sugar
# - ½ Cupful of Butter
# - Yolks of 4 Eggs
# - Whites of 4 Eggs
# - 1 Teaspoonful of Cream of Tartar
# - ¾ Cupfuls of Flour
# - Flavoring (to taste)
#
# ### Step-by-Step Instructions
# 1. Cream butter and sugar together.
# 2. Add well-beaten eggs, then fold in the cream of tartar and flour.
# 3. Bake in a moderate oven.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Cake
#
# ### Relevant Tags/Metadata
# - Baking
# - Cakes
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page38.jpg
# Extracted information for images/page38.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# - Hermits
#
# ### Ingredients
# - ½ Cup of Butter
# - ½ Cup of Molasses
# - ⅔ Cup of Brown Sugar
# - 2 Eggs
# - 1 Cup of Raisins
# - ½ Cup of Chopped Fine
# - 2 Tablespoons of Milk
# - 1 Teaspoon of Soda
# - 1 Teaspoon of Nutmeg
# - ½ Teaspoon of Cloves
# - Flour enough to roll
#
# ### Instructions
# 1. Cream the butter and sugar together.
# 2. Beat the eggs, add to the butter and sugar, then stir in the molasses, milk, and spices.
# 3. Add the raisins and mix well.
# 4. Roll thin and cut with cookie-cutter.
#
# ### Cuisine Type
# - American
#
# ### Dish Type
# - Cookie
#
# ### Relevant Tags/Metadata
# - Baking
# - Dessert
# - Traditional Recipe
#
# ---
#
# ### Recipe Title
# - Jumbles
#
# ### Ingredients
# - 2 Cups of Sugar
# - ½ Cup of Butter
# - 1 Egg
# - ½ Cup of Milk
# - 1 Teaspoon of Cream of Tartar
# - 1 Teaspoon of Lemon
# - 1 Teaspoon of Soda
# - Flour enough to roll
#
# ### Instructions
# 1. Cream together the butter and sugar.
# 2. Add the beaten egg.
# 3. Stir in the milk, cream of tartar, and soda.
# 4. Roll into rings and bake in a well-greased pan.
#
# ### Cuisine Type
# - American
#
# ### Dish Type
# - Cookie
#
# ### Relevant Tags/Metadata
# - Baking
# - Dessert
# - Traditional Recipe
#
# Processing image images/page39.jpg
# Extracted information for images/page39.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Nut Cake and Oatmeal Cookies
#
# ### Ingredients
#
# #### Nut Cake
# - 1 Cup of Sugar
# - 1 Cup of Butter
# - 2 Eggs
# - 2 Cups of Flour
# - 1 Teaspoon of Cream of Tartar
# - 1 Cup of Hickory Nut Meats or English Walnuts
#
# #### Oatmeal Cookies
# - 2 Eggs
# - 1 Cup of Sugar
# - 1½ Cups of Oatmeal or Rolled Oats
# - 1 Cup of Coconut
# - ½ Teaspoon of Salt
# - 1 Teaspoon of Vanilla
# - 2 Tablespoons of Butter
#
# ### Instructions
#
# #### Nut Cake
# 1. Cream the butter and sugar together, then add the eggs and milk.
# 2. Add the cream of tartar into the flour.
# 3. Stir all together, adding nut meats, covered with flour.
#
# #### Oatmeal Cookies
# 1. Cream the butter and sugar together and add the well-beaten eggs.
# 2. Add the remaining ingredients and mix.
# 3. Drop onto a well-greased baking pan.
# 4. Bake in a moderate oven for fifteen to twenty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Tags/Metadata
# - Baking
# - Cakes
# - Cookies
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page40.jpg
# Extracted information for images/page40.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# One, Two, Three, Four Cake
#
# ### Ingredients:
# - 1 Cupful of Butter
# - 2 Cupfuls of Sugar
# - 2 Cupfuls of Flour
# - 2 Teaspoons of Cream of Tartar
# - 1 Teaspoon of Soda
# - 2/3 Cupful of Milk
# - 3 Eggs
#
# ### Step-by-Step Instructions:
# 1. Cream the butter and sugar together and add the well-beaten eggs; beat all together.
# 2. Put in the cream of tartar and the soda into the flour; stir all together.
# 3. Bake in a slow oven. This will make two loaves.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Cake
#
# ### Relevant Tags/Metadata:
# - Baking
# - Dessert
# - Classic Recipe
#
# ---
#
# ### Recipe Title:
# Ribbon Cake
#
# ### Ingredients:
# - 3 Eggs
# - 1/2 Salt and flavor
# - 2 Cupfuls of Sugar
# - 1 Large Cupful of Milk
# - 3 Cupfuls of Flour
# - 1 Teaspoonful of Cream
# - 1/2 Pound of Cloves
# - 1 Teaspoonful of Cinnamon
# - 1/2 Nutmeg
# - 1 Tablespoonful of Molasses
# - 1/2 Teaspoon of Soda
#
# ### Step-by-Step Instructions:
# 1. Beat the eggs and sugar together.
# 2. Add the milk, salt, and soda, and cream of tartar, mixing all together.
# 3. Pour half of this mixture into two oblong pans.
# 4. In one large cupful of flour, stoned and chopped, add the remaining mixture.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Cake
#
# ### Relevant Tags/Metadata:
# - Baking
# - Dessert
# - Classic Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page41.jpg
# Extracted information for images/page41.jpg:
# Here’s the structured information extracted from the recipe page:
#
# ### Recipe Title:
# Things Mother Used to Make
#
# ### Ingredients:
# #### Roll Jelly Cake:
# - 4 Eggs
# - ½ Cup of Sugar
# - 1 Cup of Flour
# - 1 Teaspoon of Salt
# - 1 Cup of Sugar (for filling)
# - 1 Teaspoon of Extract (vanilla or other)
# - 1 Teaspoon of Cream of Tartar
#
# #### Silver Cake:
# - 1 Cup of Milk
# - 1 Scant Teaspoon of Baking Powder
# - 2 Cups of Flour
# - ⅓ Cup of Sugar
# - 8 Eggs
# - ½ Teaspoon of Soda
# - Almond Flavoring
#
# ### Step-by-Step Instructions:
# #### Roll Jelly Cake:
# 1. Beat together the eggs and sugar.
# 2. Add flour and salt, mixing well.
# 3. Stir in the extract and cream of tartar.
# 4. Spread the mixture onto a clean towel.
# 5. Bake in a moderate oven until done.
# 6. Roll the cake while warm, alternating with jelly between layers.
#
# #### Silver Cake:
# 1. Cream together the butter and sugar.
# 2. Add milk and flavoring.
# 3. Stir in the eggs.
# 4. Mix in the baking powder, flour, and soda.
# 5. Pour into a prepared pan and bake.
#
# ### Cuisine Type:
# Traditional American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Baking
# - Cakes
# - Family Recipes
# - Vintage Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page42.jpg
# Extracted information for images/page42.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Sponge Cake, No. 1
#
# ### Ingredients
# - 3 Eggs
# - 1½ Cupfuls of Flour
# - 1½ Cupfuls of Sugar
# - ½ Cupful of Water
# - Pinch of Salt
# - 1 Teaspoonful of Cream of Tartar
# - ½ Teaspoonful of Soda
#
# ### Instructions
# 1. Beat eggs and sugar together.
# 2. Add water and salt, then put soda and cream of tartar into the dry flour.
# 3. Beat all together.
# 4. Bake slowly.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags
# - Baking
# - Cake
# - Sponge Cake
#
# ---
#
# ### Recipe Title
# Sponge Cake, No. 2, Grandmother's Rule
#
# ### Ingredients
# - 4 Eggs
# - 1 Cupful of Sugar
# - 1 Cupful of Flour
# - 1 Teaspoonful of Baking-Powder
#
# ### Instructions
# 1. Beat the eggs for ten minutes, add sugar, and beat again.
# 2. Then add the flour. Stir all together and bake in a moderate oven.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags
# - Baking
# - Cake
# - Sponge Cake
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page43.jpg
# Extracted information for images/page43.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Old-Fashioned Candies
#
# ### Ingredients
# #### Chocolate Taffy
# - 1½ Cups of Molasses
# - 1½ Cups of Sugar
# - ½ Cup of Milk
# - 2 Squares of Chocolate
# - 1 Small Teaspoon of Butter
# - 1½ Cups of Flour
#
# #### Molasses Candy
# - 2 Cups of Molasses
# - ¼ Cup of Sugar
# - 2 Teaspoons of Vinegar
# - ¼ Teaspoon of Soda
# - 1 Small Teaspoon of Butter
#
# ### Step-by-Step Instructions
# #### Chocolate Taffy
# 1. Stir the sugar, flour, and grated chocolate into the molasses and milk.
# 2. When hot, add the butter. Boil until it strings.
# 3. Pour into buttered tin. When nearly cold, mark into squares.
#
# #### Molasses Candy
# 1. Put the molasses, vinegar, and butter into a saucepan.
# 2. Boil until it strings when dropped from a spoon.
# 3. When it is brittle when tested in cold water, stir the soda in briskly and pour into a buttered tin.
# 4. When nearly cold, cut into small pieces or sticks and lay on a buttered platter.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Candy
#
# ### Tags/Metadata
# - Old-fashioned
# - Candy recipes
# - Sweet treats
# - Homemade candy
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page44.jpg
# Extracted information for images/page44.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Butter Scotch
#
# ### Ingredients
# - ½ Cup of Molasses
# - ½ Cup of Butter
# - ½ Cup of Sugar
#
# ### Instructions
# 1. Boil the ingredients until it strings.
# 2. Pour into buttered tin and when cold, break into pieces.
#
# ### Cuisine Type
# Traditional/Classic
#
# ### Dish Type
# Candy/Dessert
#
# ### Relevant Tags
# - Sweet
# - Confectionery
# - Homemade
#
# ---
#
# ### Recipe Title
# Pop Corn Balls (very old recipe)
#
# ### Ingredients
# - 1 Cup of Molasses
# - Piece of Butter, half the size of an egg
# - Pinch of soda
#
# ### Instructions
# 1. Boil together until it strings and then stir in a pinch of soda.
# 2. Put this over a quart dish and cool enough to handle.
# 3. Squeeze into balls the size of an orange.
#
# ### Cuisine Type
# Traditional/Classic
#
# ### Dish Type
# Snack/Dessert
#
# ### Relevant Tags
# - Sweet
# - Snack
# - Homemade
#
# Processing image images/page45.jpg
# Extracted information for images/page45.jpg:
# Here’s the structured information extracted from the recipe page:
#
# ### Recipe Title
# Apple Tarts
#
# ### Ingredients
# - Pie crust (for pies)
# - Apples (for filling)
# - Sugar (for sweetening)
# - Optional: Cream (for serving)
#
# ### Step-by-Step Instructions
# 1. Roll pie crust thin as for pies.
# 2. Cut into rounds, pinching up the edge half an inch high and place in muffin rings.
# 3. Put into each one a tablespoon of apple sauce and bake in a hot oven for twenty minutes.
# 4. Beat the white of an egg to a stiff froth and add two tablespoons of sugar.
# 5. Drop a spoonful on the top of each and brown quickly in a hot oven.
#
# ### Cuisine Type
# Dessert
#
# ### Dish Type
# Tart
#
# ### Relevant Tags
# - Desserts
# - Baked Goods
# - Apples
#
# ---
#
# ### Recipe Title
# Baked Apples, No. 1
#
# ### Ingredients
# - Apples
# - Sugar (for sweetening)
# - Optional: Cream (for serving)
#
# ### Step-by-Step Instructions
# 1. Take good, sour apples; greens are best.
# 2. Scoop out the cores, wash and place in a baking pan.
# 3. Fill the hole with sugar and a tablespoon for each apple besides.
# 4. Pour over these a generous supply of cream.
# 5. Bake in a hot oven until light and fluffy.
# 6. Serve as a delicious dessert, if served with cold cream.
#
# ### Cuisine Type
# Dessert
#
# ### Dish Type
# Baked Apples
#
# ### Relevant Tags
# - Desserts
# - Baked Goods
# - Apples
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page46.jpg
# Extracted information for images/page46.jpg:
# Here’s the structured information extracted from the recipe page:
#
# ### Recipe Title
# Baked Sweet Apples
#
# ### Ingredients
# - 3 to 6 apples
# - Molasses (amount not specified)
# - Sugar (optional, to taste)
# - Milk (for serving)
#
# ### Instructions
# 1. Wash clean, pare, and slice the apples.
# 2. Put these into a baking pan with a little cold water.
# 3. Add molasses, if desired.
# 4. Bake for three to four hours until they are a dark amber color.
# 5. Serve with crackers and milk.
#
# ---
#
# ### Recipe Title
# Apple Dumplings
#
# ### Ingredients
# - Pie crust
# - Apples (amount not specified)
# - Sugar (for sprinkling)
# - Butter (for topping)
#
# ### Instructions
# 1. Take pie crust, roll thin for pie and cut into rounds as large as a tea saucer.
# 2. Pare and slice fine, one small apple for each dumpling.
# 3. Lay the apple on the crust, sprinkle with sugar, and dot with butter.
# 4. Fold the crust edges over the apple and press together.
# 5. Bake in a hot oven for twenty minutes.
# 6. Serve hot with cold sauce.
#
# ---
#
# ### Recipe Title
# Fried Apples
#
# ### Ingredients
# - Apples (amount not specified)
# - Sugar (to taste)
# - Butter (for frying)
#
# ### Instructions
# 1. Pare and slice apples.
# 2. Fry in hot fat.
# 3. When removed from the fire, sprinkle over them a little sugar.
# 4. Bananas are nice cooked in the same way.
#
# ---
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags
# - Apples
# - Baking
# - Dumplings
# - Fried Desserts
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page47.jpg
# Extracted information for images/page47.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Bramberries
#
# ### Ingredients
# **Crust:**
# - 1½ Cups of Flour
# - ½ Cup of Lard
# - 1 Cup of Raisins
# - 1 Cracker
# - ½ Teaspoon of Salt
# - Just enough Water to wet smooth
#
# **Filling:**
# - 1 Egg
# - A Little Salt
#
# ### Instructions
# 1. Beat the egg, add sugar, salt, lemon juice, and grated rind.
# 2. Roll cracker fine, chop raisins and mix all together.
# 3. Roll the crust thin to 2 pounds.
# 4. Put a spoonful of filling in the center of each piece.
# 5. Fold over and pinch together.
# 6. Prick top crust with fork.
# 7. Bake in iron pan for twenty minutes.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Dessert
#
# ### Tags/Metadata
# - Baking
# - Sweet
# - Raisins
# - Egg-based
#
# ---
#
# ### Recipe Title
# Cream Puffs
#
# ### Ingredients
# - 1 Cup of Hot Water
# - ½ Cup of Flour
# - 1 Pinch of Salt
# - 1 Teaspoon of Baking Soda
# - 4 Eggs
#
# ### Instructions
# 1. In a dish on the stove, bring hot water to a boil.
# 2. While boiling, stir in the flour and salt.
# 3. Add eggs one at a time, mixing well after each addition.
# 4. When the batter is smooth and thick, drop on a buttered pan.
# 5. Bake for twenty minutes at a hot oven.
# 6. When done, make a slit in the side with a knife.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Pastry
#
# ### Tags/Metadata
# - Baking
# - Sweet
# - Egg-based
# - Pastry
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page48.jpg
# Extracted information for images/page48.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Floating Island
#
# ### Ingredients:
# - 1 Quart of Milk
# - 4 Eggs
# - 1 Cupful of Sugar
# - 1 Teaspoon of Cornstarch
# - 1 Teaspoon of Vanilla
# - Pinch of Salt
# - 1 Tablespoon of Lemon (for flavor)
#
# ### Step-by-Step Instructions:
# 1. Put the milk on the stove and heat to nearly boiling point.
# 2. Separate the eggs; beat the egg whites until stiff and drop them by spoonfuls into the hot milk.
# 3. Cook these spoonfuls until they are set, then remove them with a slotted spoon.
# 4. In a separate bowl, mix the egg yolks with sugar, salt, and cornstarch.
# 5. Stir this mixture into the boiling milk and let it boil.
# 6. Flavor and cool. Turn into a glass dish and lay the "islands" on top of the custard.
# 7. Serve cold.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Egg-based dessert
# - Custard
# - Classic recipe
# - Sweet dish
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page49.jpg
# Extracted information for images/page49.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Things Mother Used to Make
#
# ### Ingredients:
# #### Coffee Jelly:
# - 1 Small Box of Gelatine
# - 1 Pint of Strong Coffee
# - 1 Cupful of Sugar
# - 1 Scent Quart of Boiling Water
# - Flavor with Vanilla
#
# #### Lemon Jelly:
# - 1½ Box of Gelatine
# - 1 Cupful of Sugar
# - 3 Lemons
# - 1 Cupful of Cold Water
# - 2 Quarts of Boiling Water
#
# ### Instructions:
# #### Coffee Jelly:
# 1. Soak the gelatine in cold water for fifteen minutes.
# 2. Stir into the coffee and add sugar and water, then vanilla.
# 3. Pour into a mold and set away to cool.
# 4. Serve with cold sauce or cream and sugar.
#
# #### Lemon Jelly:
# 1. Soak gelatine in cold water for half an hour.
# 2. Add boiling water, sugar, and juice of lemons.
# 3. Stir well and strain into mold or small cups.
#
# ### Cuisine Type:
# Traditional
#
# ### Dish Type:
# Dessert
#
# ### Tags/Metadata:
# - Gelatine
# - Coffee
# - Lemon
# - Sweet
# - Chilled Dessert
#
# Processing image images/page50.jpg
# Extracted information for images/page50.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Strawberry Shortcake
#
# ### Ingredients
# - **For the Shortcake:**
#   - 1 Pint of Flour
#   - ⅓ Cupful of Lard
#   - 1 Cupful of Milk
#   - 2 Teaspoons of Cream of Tartar
#   - 1 Teaspoon of Soda
#   - 1 Cupful of Strawberries
#
# - **For the Topping:**
#   - 1 Tablespoon of Butter
#   - ½ Cupful of Milk
#   - ½ Cupful of Strawberries
#   - 1 Teaspoon of Soda
#   - 1 Cupful of Cream
#
# ### Step-by-Step Instructions
# 1. **Prepare the Shortcake:**
#    - Mix the flour, soda, lard, and cream of tartar in a bowl.
#    - Add the milk (with water if needed) to form a stiff dough.
#    - Divide the dough into two parts for a Washington pie tin.
#    - Spread butter on the bottom and place the dough on top.
#    - Bake for twenty minutes.
#
# 2. **Prepare the Topping:**
#    - Cream together the butter and add the well-beaten egg and milk.
#    - Mix in the strawberries and sweeten to taste.
#    - Put the topping on the shortcake and layer with the whipped cream.
#
# 3. **Assemble:**
#    - Place the two cakes together and top with the whipped cream and remaining strawberries.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Tags/Metadata
# - Strawberry
# - Shortcake
# - Baking
# - Summer Dessert
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page51.jpg
# Extracted information for images/page51.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title:
# To Boil Eggs
#
# ### Ingredients:
# - Eggs
# - Salt (for boiling water)
# - Bread (for toast)
# - Butter (for spreading)
# - Pepper (for seasoning)
#
# ### Step-by-Step Instructions:
# 1. Put your eggs into a bowl which can be sent to the table.
# 2. Pour boiling water over the eggs and let sit for 8 to 10 minutes.
# 3. Ensure the water is boiling.
# 4. For the toast:
#    - Toast as many slices of bread as desired.
#    - Butter the slices and pour over just enough salted water to soften.
#    - Round and mix with a spoon, break the egg and drop into the swirling water.
#    - Remove from the water in four to six minutes, as preferred.
#    - Place on one slice of bread and serve hot, with a dash of pepper.
#
# ### Cuisine Type:
# General
#
# ### Dish Type:
# Breakfast
#
# ### Relevant Tags/Metadata:
# - Eggs
# - Boiling
# - Toast
# - Breakfast Recipe
# - Simple Cooking
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page52.jpg
# Extracted information for images/page52.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Plain Omelette
#
# ### Ingredients
# - 2 Eggs
# - Pinch of Salt
# - 2 Spoonfuls of Water
#
# ### Instructions
# 1. Beat the eggs and yolk separately.
# 2. Add salt and water.
# 3. Pour into a hot frying pan and fry until it is puffed up.
# 4. Turn half over and serve at once.
#
# ---
#
# ### Recipe Title
# Ham Omelette
#
# ### Ingredients
# - 2 Eggs
# - Chopped boiled ham (about two-thirds of a cup)
#
# ### Instructions
# 1. Make a plain omelette.
# 2. Pour into the hot frying pan and cook both sides.
#
# ---
#
# ### Recipe Title
# New England Poached Eggs
#
# ### Ingredients
# - 4 Eggs
# - 8 Tablespoonfuls of Milk
# - Butter (the size of a walnut)
# - ½ Teaspoonful of Salt
#
# ### Instructions
# 1. Break the eggs into a sauce pan with milk, salt, and butter.
# 2. Cook until they thicken, stirring constantly.
# 3. Serve hot with a dash of pepper.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Breakfast
#
# ### Tags/Metadata
# - Omelette
# - Poached Eggs
# - Breakfast Recipes
# - Simple Recipes
#
# Processing image images/page53.jpg
# Extracted information for images/page53.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Clam Fritters
#
# ### Ingredients
# - **For Clam Fritters:**
#   - 1 Egg
#   - 1 Cupful of Milk
#   - 1 Cupful of Bread-flour and a little extra for dusting
#   - Salt (to taste)
#
# - **For Fish Balls:**
#   - 1 Cupful of Hot Mashed Potatoes
#   - ½ Cupful of Shredded Cod-fish
#   - 2 Teaspoons of Melted Butter
#   - 1 Cupful of Milk (for boiling)
#
# ### Step-by-Step Instructions
# 1. **For Clam Fritters:**
#    - Beat the egg and half of the milk, adding the flour gradually to make the batter smooth.
#    - Add the last half-cupful of milk and salt to taste.
#    - Serve hot.
#
# 2. **For Fish Balls:**
#    - Put the fish into a piece of cheese-cloth, let cold water run over it, and squeeze out the water.
#    - Mix all ingredients together.
#    - Take a little flour in the hand and roll half a tablespoon of the mixture between the palms to form balls.
#    - Deep fry in hot fat.
#
# ### Cuisine Type
# Seafood
#
# ### Dish Type
# Appetizer/Main Course
#
# ### Relevant Tags/Metadata
# - Seafood
# - Fritters
# - Frying
# - Comfort Food
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page54.jpg
# Extracted information for images/page54.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Baked Mackerel
#
# ### Ingredients
# - 1 Mackerel
# - 3 Small Slices of Salt Pork
# - Salt to Taste
#
# ### Instructions
# 1. Split open the mackerel and remove the insides.
# 2. Wash clean and lay in a baking-pan on a buttered paper or cheese-cloth.
# 3. Place the slices of salt pork over the mackerel.
# 4. Season with salt to taste.
#
# ### Cuisine Type
# Seafood
#
# ### Dish Type
# Main Course
#
# ### Tags/Metadata
# - Fish
# - Baking
# - Simple Recipe
# - Traditional Cooking
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page55.jpg
# Extracted information for images/page55.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Oysters on Toast
#
# ### Ingredients:
# - Oysters
# - Bread (sliced)
# - Pepper
# - Salt
# - White sauce (for serving)
#
# ### Instructions:
# 1. Toast as many slices of bread as desired.
# 2. Wipe the oysters to cover them and season with pepper and salt.
# 3. Place the hot oysters over the toasted bread, allowing them to extend to the edges.
# 4. Serve hot with a white sauce.
#
# ### Cuisine Type:
# Seafood
#
# ### Dish Type:
# Appetizer
#
# ### Relevant Tags:
# - Oysters
# - Toast
# - Quick Recipe
# - Seafood Dish
#
# ---
#
# ### Recipe Title:
# Baked Shad
#
# ### Ingredients:
# - A nice dressing of five or six crackers (bread crumbs)
# - Poultry dressing
# - Salt
# - Small piece of liver
# - Large sheet of white paper
# - Baking pan
# - Piece of cheese-cloth
#
# ### Instructions:
# 1. Make a nice dressing using the crackers and poultry dressing.
# 2. Roll the shad in the mixture and soak in water.
# 3. Season with salt and add a small piece of liver.
# 4. Wash the shad and stuff it.
# 5. Have a large sheet of white paper, well buttered, or a piece of cheese-cloth.
# 6. Put into a baking-pan and bake in the same way as mackerel.
#
# ### Cuisine Type:
# Fish
#
# ### Dish Type:
# Main Course
#
# ### Relevant Tags:
# - Shad
# - Baked Fish
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page56.jpg
# Extracted information for images/page56.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title:
# A La Mode Beef
#
# ### Ingredients:
# - 3 Pounds of Beef
# - 6 Onions
# - 4 or 5 White Turnips
# - Potatoes
# - Salt
#
# ### Instructions:
# 1. Take the meat from a cheap cut of beef. Wash, put into an iron pan, and sprinkle over it salt to taste.
# 2. Pare six onions or more, according to size of family, and prepare four or five small white turnips sliced thin.
# 3. Lay these around the meat and pour over all a quart of cold water. Put into the oven and bake three hours.
# 4. Pare potatoes enough for the serving, putting them in an hour and a half before serving.
# 5. This is a most delicious way to cook beef. As the water cooks away, thicken the gravy with your roast meat.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Meat Dish
#
# ### Tags/Metadata:
# - Comfort Food
# - Slow Cooking
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page57.jpg
# Extracted information for images/page57.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Beef Stew with Dumplings
#
# ### Ingredients
# #### For Beef Stew
# - 3 pounds of meat
# - 2 large onions
# - 6 potatoes
# - 1 tablespoon of salt
# - Water
#
# #### For Dumplings
# - 2 cups of flour
# - 1 teaspoon of baking soda
# - ½ teaspoon of cream of tartar
# - 1 glass of water
#
# ### Step-by-Step Instructions
# 1. Wash the meat, put it into a kettle, cover with cold water, and bring to a boil.
# 2. After boiling, skim off the scum and add the onions, salt, and potatoes.
# 3. Cover the kettle with a lid and allow to simmer for two hours.
# 4. Prepare the dumplings by mixing the flour, baking soda, and cream of tartar in a bowl.
# 5. Add water to the dry ingredients and mix until combined.
# 6. Roll out the dough on a plate, cut into pieces, and drop into the stew.
# 7. Cook for an additional twenty minutes.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Main Course
#
# ### Tags/Metadata
# - Comfort Food
# - Hearty Meal
# - Family Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page58.jpg
# Extracted information for images/page58.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# New England Boiled Dinner
#
# ### Ingredients
# - Corned beef
# - Water
# - Potatoes (e.g., baked, beets, turnips, squash, parsnips, and carrots)
# - Cabbage
# - Salt
# - Pepper
#
# ### Step-by-Step Instructions
# 1. Boil the corned beef for four hours.
# 2. Add the cabbage and one hour later, add the potatoes, carrots, and parsnips.
# 3. Boil until the vegetables are tender.
# 4. Slice the potatoes, pare and slice the squash, and pick the outer leaves from the cabbage.
# 5. Drop the vegetables into cold water and slice the corned beef.
#
# ### Cuisine Type
# New England
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags/Metadata
# - Comfort Food
# - Traditional
# - Boiled Dinner
#
# ---
#
# ### Recipe Title
# Brunswick Stew
#
# ### Ingredients
# - Chicken or Lamb (3 pounds)
# - 4 Ears of Corn
# - Salt and Pepper
# - Tomatoes (canned or fresh)
# - Onions (chopped)
#
# ### Step-by-Step Instructions
# 1. Cook the chicken or lamb until tender.
# 2. Take from the water and cut into pieces.
# 3. Put the meat back into the liquid along with the corn, tomatoes, and onions.
# 4. Cook until everything is well combined and heated through.
#
# ### Cuisine Type
# Southern
#
# ### Dish Type
# Stew
#
# ### Relevant Tags/Metadata
# - Hearty
# - Comfort Food
# - Southern Cuisine
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page59.jpg
# Extracted information for images/page59.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title:
# Corn Beef Hash
#
# ### Ingredients:
# - Corned Beef
# - Milk
# - Potatoes
# - Salt
# - Pepper
# - Lump of Butter
#
# ### Instructions:
# 1. **Prepare the Potatoes**: Chop the potatoes into small pieces or a little more.
# 2. **Cook the Potatoes**: Put into a saucepan or a large kettle. Cover with water and bring to a boil.
# 3. **Add Corned Beef**: When the potatoes are almost done, add the corned beef, a little salt, and pepper.
# 4. **Mix Ingredients**: Loosen with a fork, then add milk to taste.
# 5. **Finish Cooking**: Turn warm and allow to cook until everything is heated through.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Main Course
#
# ### Tags/Metadata:
# - Comfort Food
# - Traditional Recipe
# - Hearty Meal
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page60.jpg
# Extracted information for images/page60.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Breaded Pork Chops
#
# ### Ingredients
# - 6 Chops
# - 1 Egg
# - ½ Cup of Bread Crumbs
# - Pinch of Salt
# - ½ Cup of Milk
#
# ### Instructions
# 1. Beat the egg and milk together.
# 2. Dip the chops into the mixture, then coat with bread crumbs.
# 3. Fry in hot fat until golden brown.
# 4. Serve with a pinch of salt.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags
# - Pork
# - Breaded
# - Frying
# - Comfort Food
#
# ---
#
# ### Recipe Title
# Potted Beef
#
# ### Ingredients
# - 3 Pounds of a Cheap Cut of Beef
# - ½ Can of Tomatoes
# - Salt to taste
# - Onions
#
# ### Instructions
# 1. Put the meat into a kettle, cover with cold water, and boil slowly for two hours.
# 2. Add salt and onions, cut into quarters.
# 3. Boil all together, and as the water boils away, add more.
# 4. Serve the meat hot. The liquor makes a delicious soup, thickened with two potatoes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags
# - Beef
# - Stew
# - Comfort Food
#
# ---
#
# ### Recipe Title
# A Fine Way to Cook Veal
#
# ### Ingredients
# - 2 Pounds of Veal
# - 1 Egg
# - ½ Cup of Milk
# - Salt and Pepper to taste
#
# ### Instructions
# 1. Cut the veal into small pieces.
# 2. Season with salt and pepper.
# 3. Prepare as desired.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags
# - Veal
# - Cooking Method
# - Comfort Food
#
# Processing image images/page61.jpg
# Extracted information for images/page61.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Veal Patties
#
# ### Ingredients
# - 1½ Cupfuls of Boiled Rice
# - 1 Cupful of Veal
# - 1 Egg
# - 1 Tablespoon of Milk
# - ½ Teaspoon of Poultry Seasoning
# - Salt (to taste)
# - Lard (for frying)
#
# ### Instructions
# 1. Grind or chop the veal, salt, and stir into the rice with the seasoning.
# 2. Beat the egg, add milk, and stir all together.
# 3. Drop a tablespoonful of the mixture onto a hot griddle.
# 4. Cook slowly for ten minutes, turning once.
#
# ### Cuisine Type
# Traditional/Comfort Food
#
# ### Dish Type
# Main Course
#
# ### Tags/Metadata
# - Veal
# - Rice
# - Frying
# - Comfort Food
# - Family Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page62.jpg
# Extracted information for images/page62.jpg:
# Here’s the structured information extracted from the recipe content:
#
# ### Recipe Title:
# Boston Baked Beans
#
# ### Ingredients:
# - 3 cups small white beans
# - 7 teaspoons sugar
# - 1 teaspoon salt
# - ½ pound pork (or other meat)
# - Water (for soaking and boiling)
#
# ### Instructions:
# 1. Pick over and wash three cups of small white beans; cover with cold water and soak overnight.
# 2. In the morning, put them on the stove in just enough water to cover, and do not boil.
# 3. Pour off the water and put into an earthen bean-pot.
# 4. Add seven teaspoons of sugar, one teaspoon of salt, one half-pound of pork, and fat in the bean pot.
# 5. Cover with water, and bake from eight A.M. until six P.M. As the water boils away, add more.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Main Dish
#
# ### Tags/Metadata:
# - Baked Beans
# - Comfort Food
# - Traditional Recipe
#
# ---
#
# ### Recipe Title:
# A Breakfast Dish
#
# ### Ingredients:
# - 4 Boston crackers
# - 1 cup of tea (or other liquid)
#
# ### Instructions:
# 1. Take stale Boston crackers, split open, toast to a delicate brown on each side.
# 2. Put these into a bowl or earthen dish of some kind, and pour over them a cup of tea.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Breakfast
#
# ### Tags/Metadata:
# - Breakfast
# - Quick Recipe
# - Comfort Food
#
# Feel free to use this structured information for your Retrieval Augmented Generation (RAG) system!
#
# Processing image images/page63.jpg
# Extracted information for images/page63.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Grape Juice
#
# ### Ingredients
# - 3 Pounds of Grapes
# - 1 Cupful of Water
#
# ### Instructions
# 1. Pick from the stems and wash clean, ten pounds of grapes.
# 2. Put them on the stove in a kettle, with a little water, and cook until tender.
# 3. Strain through a flannel bag.
# 4. Return juice to the kettle, and agitate, and boil for five minutes.
# 5. Seal in glass jars when boiling hot. Slant the jars when filling, to prevent cracking.
# 6. When serving, add nearly the same amount of water.
#
# ### Cuisine Type
# Traditional/Preserved Foods
#
# ### Dish Type
# Beverage
#
# ### Tags/Metadata
# - Homemade
# - Fruit Juice
# - Preservation
# - Non-Alcoholic
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page64.jpg
# Extracted information for images/page64.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Minced Meat
#
# ### Ingredients
# - 4 Cupfuls of Chopped Meat
# - 12 Cupfuls of Chopped Vegetables
# - 2 Cupfuls of Vinegar
# - 5 Cupfuls of Seeded Raisins
# - 1 Cupful of Currants
# - 2/3 Cupful of Brown Sugar
# - 1 ½ Cupfuls of Molasses
# - 1 Teaspoon of Cinnamon
# - 1 Teaspoon of Nutmeg
# - ½ Pound of Citron
# - 1 Egg
# - Coffee or strong tea (for moistening)
#
# ### Instructions
# 1. Moisten with cold coffee or strong tea.
# 2. Combine all ingredients.
# 3. Cook slowly for two hours.
#
# ### Cuisine Type
# Traditional/Comfort Food
#
# ### Dish Type
# Main Dish
#
# ### Relevant Tags
# - Meat Dish
# - Sweet and Savory
# - Slow Cooked
#
# ---
#
# ### Recipe Title
# Home-made Potato Yeast
#
# ### Ingredients
# - 4 Good-sized Potatoes
# - 1 Quart of Boiling Water
# - 2/3 Cupful of Sugar
# - 1 ½ Cupful of Salt
# - 1 Package of Old Yeast
#
# ### Instructions
# 1. Peel and mash the potatoes.
# 2. Add the boiling water and mix well.
# 3. Let the mixture cool to a lukewarm temperature.
# 4. Stir in the sugar and salt.
# 5. Add the yeast and mix until combined.
# 6. Place in a pitcher or container and allow to rise; keep covered.
# 7. Use two tablespoons in place of one quart of flour.
#
# ### Cuisine Type
# Traditional/Comfort Food
#
# ### Dish Type
# Baking Ingredient
#
# ### Relevant Tags
# - Yeast
# - Homemade
# - Baking
#
# Processing image images/page65.jpg
# Extracted information for images/page65.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Mince Meat
#
# ### Ingredients:
# - 4 Cupfuls of Chopped Meat
# - 2 Cupfuls of Chopped Apples
# - 2 Cupfuls of Chopped Suet
# - 4 Cupfuls of Seeded Raisins
# - 1 Cupful of Currants
# - 5 Cupfuls of Brown Sugar
# - 1⅓ Cupfuls of Molasses
# - 6 Teaspoons of Cinnamon
# - 1 Lemon (Juice and Rind)
# - 1 Egg (for the wash)
#
# ### Instructions:
# 1. Moisten with cold coffee or strong tea.
# 2. Cook slowly for several hours.
#
# ### Cuisine Type:
# Traditional/Heritage
#
# ### Dish Type:
# Preserved Meat
#
# ### Relevant Tags/Metadata:
# - Mince Meat
# - Holiday Recipe
# - Preserving
# - Traditional Cooking
#
# ---
#
# ### Recipe Title:
# Home-made Potato Yeast
#
# ### Ingredients:
# - 4 Good-Sized Potatoes
# - 1⅓ Cupfuls of Salt
# - 2 Cupfuls of Sugar
#
# ### Instructions:
# 1. Boil, peel, and mash the potatoes; add the boiling water, sugar, and salt.
# 2. If yeast cannot be obtained, use this into a pitcher or container that will hold three pints; place in a warm place, covered.
# 3. Use two-thirds of a cup in one quart of flour.
#
# ### Cuisine Type:
# Traditional/Heritage
#
# ### Dish Type:
# Yeast Preparation
#
# ### Relevant Tags/Metadata:
# - Yeast
# - Homemade
# - Baking
# - Traditional Cooking
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page66.jpg
# Extracted information for images/page66.jpg:
# ...
#    - Instead of rolling and cutting as usual, drop the dough into a large iron pan. The heat of the oven will shape it.
#
# ### Cuisine Type
# Preservation Techniques
#
# ### Dish Type
# Condiments / Side Dishes
#
# ### Relevant Tags
# - Food Preservation
# - Cooking Tips
# - Pickling
# - Baking Techniques
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page117.jpg
# Extracted information for images/page117.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# How to Add Salt to Milk
#
# ### Ingredients
# - New milk
# - Salt
# - Flour (optional)
# - Eggs (optional)
#
# ### Instructions
# 1. Salt will curdle new milk, so when making gravies or puddings, put your salt into the flour or with eggs.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Not specified
#
# ### Tags/Metadata
# - Cooking Tips
# - Dairy
# - Curdling Process
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page118.jpg
# Extracted information for images/page118.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# Salted Almonds
#
# ### Ingredients
# - Nuts (almonds)
# - Salt
# - Butter or olive oil (optional)
#
# ### Instructions
# 1. Shell the nuts and put them in a double boiler.
# 2. Allow the nuts to stand for fifteen to twenty minutes.
# 3. If desired, add a tablespoon of olive oil or butter.
# 4. Sprinkle a teaspoon of salt over the nuts.
# 5. Spread the nuts on a pan and place in a hot oven.
# 6. Watch closely and stir several times to prevent burning.
#
# ### Cuisine Type
# Snack
#
# ### Dish Type
# Nut Snack
#
# ### Tags/Metadata
# - Easy
# - Quick
# - Snack
# - Oven-baked
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page119.jpg
# Extracted information for images/page119.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# Before Washing Colored Clothes
#
# ### Ingredients
# - Salt (to soak clothes)
# - Lemon table salt (for removing rust)
# - Starch (for making a smooth paste)
#
# ### Step-by-Step Instructions
# 1. **Soaking Colored Clothes**:
#    - Set the colored clothes in a strong solution of cold water with salt for two hours.
#
# 2. **Removing Iron Rust from White Goods**:
#    - Sprinkle lemon table salt on the rust spot.
#    - Leave the item in the sun for a while to remove the spot.
#
# 3. **Making Starch Paste**:
#    - Mix two tablespoons of starch with four tablespoons of cold water to create a smooth paste.
#    - Pour over three pints of boiling water, stirring until the mixture thickens.
#
# ### Cuisine Type
# N/A (Household care)
#
# ### Dish Type
# N/A (Laundry care)
#
# ### Relevant Tags/Metadata
# - Laundry tips
# - Stain removal
# - Household cleaning
# - Fabric care
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page120.jpg
# Extracted information for images/page120.jpg:
# Based on the content of the image, here is the structured information extracted for the recipe:
#
# ### Recipe Title
# The Proper Way to Sweep a Room
#
# ### Ingredients
# - Dust bric-a-brac
# - Newspaper
# - Water
# - Ammonia
# - Mild scrubbing brush
# - Pan of hot water
#
# ### Step-by-Step Instructions
# 1. Dust the furniture and bric-a-brac in the room.
# 2. If sweeping a bedroom, remove items from the bed.
# 3. Sweep the floor, starting from the edges and moving inward.
# 4. Move every piece of furniture before sweeping.
# 5. If the dust is settled, fill a pail with warm water and add a tablespoon of ammonia.
# 6. Use a clean cloth to wipe down windows and glass.
# 7. Polish with dry cloth.
# 8. Wipe all furniture and surfaces with the ammonia solution.
# 9. After sweeping, place the bric-a-brac back in its original position.
#
# ### Cuisine Type
# N/A (Housekeeping)
#
# ### Dish Type
# N/A (Housekeeping)
#
# ### Relevant Tags or Metadata
# - Housekeeping
# - Cleaning
# - Home Care
# - Maintenance
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page121.jpg
# Extracted information for images/page121.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# When Using Currants and Raisins
#
# ### Ingredients
# - Currants
# - Raisins
# - Pudding or similar dish base
#
# ### Instructions
# 1. Mix a little dry flour with currants and raisins before adding them to cakes or puddings.
# 2. This will prevent them from falling to the bottom.
#
# ### Cuisine Type
# General Cooking Tips
#
# ### Dish Type
# Baking
#
# ### Relevant Tags
# - Baking Tips
# - Ingredient Preparation
# - Pudding
#
# ---
#
# If you need further assistance or additional recipes, feel free to ask!
#
# Processing image images/page122.jpg
# Extracted information for images/page122.jpg:
# I can't analyze the content of the image directly, but I can help you format a recipe if you provide the text or details from it. Please share the recipe title, ingredients, instructions, and any other relevant information, and I'll assist you in structuring it for a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page123.jpg
# Extracted information for images/page123.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# - Teach a Child to Hang up His Own Coat and Hat
#
# ### Ingredients
# - Ribbon
# - Tape (narrow white tape)
# - Glass paper
# - Clean cloth
# - Soap (white or baby soap)
# - Water (cold and hot)
# - Horse radish (for washing lace)
#
# ### Step-by-Step Instructions
# 1. **For Hanging Up a Coat and Hat:**
#    - Sew one end of the ribbon to the coat sleeve.
#    - The child can remove the mittens at any time and learn where to hang them.
#
# 2. **To Keep Your Own Umbrella:**
#    - Take a piece of narrow white tape, three or four inches long.
#    - With a glass pen, write a new clean set, and indelibly ink your name upon it.
#    - Sew this to the inside of the umbrella.
#
# 3. **To Wash a White Silk Waist or Baby's Ponsnet:**
#    - Use cold water and white soap. Hot water will turn white silk yellow.
#
# 4. **When Ironing Embroidery:**
#    - Right side down on a piece of flannel is not at hand, try an old Turkish towel.
#
# 5. **To Wash Small Pieces of Lace:**
#    - Put in a horse radish bottle and pour over them strong soap suds, and shake well. Let sit.
#
# ### Cuisine Type
# - Not applicable (the content is more instructional than culinary).
#
# ### Dish Type
# - Not applicable (the content is more instructional than culinary).
#
# ### Relevant Tags/Metadata
# - Childcare
# - Sewing
# - Household Tips
# - Cleaning
# - Maintenance
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page124.jpg
# Extracted information for images/page124.jpg:
# It seems that the image contains text related to various tips and instructions rather than a specific recipe. However, I can help you structure the information based on the content provided. Here’s a structured format:
#
# ### Recipe Information
#
# - **Title**: Not specified (contains various tips)
#
# - **Ingredients**:
#   - Graham bread
#   - Gingerbread
#   - Brown bread
#   - Cracker boxes
#   - Doughnuts
#   - Biscuit
#   - Butter (optional)
#
# - **Instructions**:
#   1. Stand while shaking the mixture.
#   2. Rinse in clear, warm water.
#   3. Dry on a clean cloth in the sunshine.
#   4. Set the milk on the back of the stove to thicken.
#   5. Strain through a cloth.
#   6. Put in a small salt, a small piece of butter, and a little sugar if desired.
#   7. Press into pans and serve.
#
# - **Cuisine Type**: Not specified
#
# - **Dish Type**: Not specified
#
# - **Tags/Metadata**:
#   - Tips for using sour milk
#   - Kitchen advice
#   - Economic cooking
#
# If you have a specific recipe in mind or need further assistance, feel free to ask!
#
# Processing image images/page125.jpg
# Extracted information for images/page125.jpg:
# It seems that the image contains text related to various tips and tricks rather than a specific recipe. Here’s a structured extraction based on the content provided:
#
# ### Recipe Information
#
# - **Title**: Tips for Household Management
# - **Ingredients**:
#   - Ironing wax
#   - Newspaper
#   - String
#   - Packing paper
#   - Fish or fowl (for cooking)
#   - Broken china or glass (for repair)
#   - Plaster of Paris
#   - Cream (for jewelry cleaning)
#
# - **Instructions**:
#   1. Save coupons for your iron.
#   2. Put a good layer of salt on newspaper and rub the irons.
#   3. Save your string for wrapping packages.
#   4. Make a bag of pretty cretonne for hanging in the kitchen or cellar.
#   5. Do not throw away small pieces of bread; save them for puddings or fish.
#   6. If broken into small pieces, store in a jar to be used for bread or other dishes.
#   7. To mend broken china, mix arable plaster with cream and press together.
#   8. For cleaning jewelry, use a little ammonia.
#
# - **Cuisine Type**: N/A
# - **Dish Type**: N/A
# - **Tags/Metadata**: Household tips, DIY, kitchen management, repair techniques, cleaning methods.
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page126.jpg
# Extracted information for images/page126.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# Dish Washing Made a Pleasure
#
# ### Ingredients
# - Dish cloth (can be a soft, clean cloth)
# - Soap (for washing dishes)
#
# ### Step-by-Step Instructions
# 1. Remove all refuse from the dishes.
# 2. Place them near the sink, starting with the larger items.
# 3. Fill a large pan with very hot water.
# 4. Wash the tumblers and all glassware first, using a soap shaker.
# 5. Wash the dishes in the following order:
#    - Tumblers
#    - Plates
#    - Bowls
#    - Pans
# 6. Always have a cake of soap handy for cleaning.
# 7. Rinse dishes thoroughly, especially the bottoms.
# 8. Wash the kitchen utensils daily, ensuring they are clean.
# 9. Use a soap shaker to make the process easier.
#
# ### Cuisine Type
# N/A (not a food recipe)
#
# ### Dish Type
# N/A (not a food recipe)
#
# ### Relevant Tags or Metadata
# - Cleaning
# - Dishwashing
# - Household tips
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page127.jpg
# Extracted information for images/page127.jpg:
# It seems that the image contains text related to a recipe or cooking tips. However, I can't extract specific recipe information like title, ingredients, or instructions from the image. If you can provide the text or details from the image, I can help you format that information for a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page128.jpg
# Extracted information for images/page128.jpg:
# It seems that the image contains text related to cooking tips rather than a specific recipe. Here’s a structured extraction based on the content provided:
#
# ### Recipe Information
#
# **Title:** Cooking Tips
#
# **Ingredients:**
# - None specified (the text provides tips rather than a recipe with ingredients).
#
# **Instructions:**
# 1. When bread cooks too quickly, use a clean piece of brown paper to prevent burning.
# 2. To remove the odor of onions, fill kettles and saucepans with water and a tablespoon of bread. Let stand until the water cools, then rinse well.
# 3. To absorb gases in a room, place a glass of water in the room to help with the respiration of the sleeping person.
#
# **Cuisine Type:** General Cooking Tips
#
# **Dish Type:** N/A
#
# **Tags/Metadata:**
# - Cooking Tips
# - Kitchen Hacks
# - Odor Removal
# - Bread Cooking
# - Water Absorption
#
# This format should be suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page129.jpg
# Extracted information for images/page129.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# What to Serve With Meats
#
# ### Ingredients
# - 1 Pint of granulated sugar (1 pound)
# - 1 Coffee-cupful of cold butter (pressed down equals a cup)
# - Squash
# - Turnips
# - Onions
# - Cranberry sauce
# - Spinach
# - Mutton
# - Currant jelly
# - Vegetables (various kinds)
#
# ### Step-by-Step Instructions
# 1. For vegetables, boil them in a little salt when cooking. Do not wait until the vegetables are done; salt the water as they are added in after they begin to boil.
#
# ### Cuisine Type
# Traditional/General
#
# ### Dish Type
# Side Dishes
#
# ### Relevant Tags/Metadata
# - Roasted meats
# - Accompaniments
# - Vegetables
# - Sauces
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page130.jpg
# Extracted information for images/page130.jpg:
# Based on the content of the image, here is the structured information extracted for the recipe:
#
# ### Recipe Title
# The Length of Time to Cook Meats
#
# ### Ingredients
# - Lamb
# - Veal
# - Ordinary size ham
# - Water
# - Salt
# - Vinegar
# - Sugar
# - Cloves
#
# ### Step-by-Step Instructions
# 1. **Lamb:**
#    - Wash clean, sprinkle over it a little flour and salt, and put into a pan with cold water.
#    - While it is cooking, take a spoon and pour over it the water from the pan for three or four times.
#
# 2. **Veal:**
#    - Roast veal treating it the same way as lamb.
#    - After removing it from the pan, make a smooth paste by wetting two or three tablespoonfuls of flour with cold water, and stir into the water left in the pan.
#    - Pour in more water if the size of your family requires it.
#
# 3. **Ham:**
#    - Boil a ham of ordinary size for three hours.
#    - Let cool in the water in which it is boiled.
#    - It is very nice to remove the skin while warm, stick cloves in the outside, sprinkle over it a little vinegar and sugar, and bake for one hour.
#
# ### Cuisine Type
# Traditional Cooking
#
# ### Dish Type
# Meat Dishes
#
# ### Relevant Tags
# - Cooking Times
# - Meat Preparation
# - Roasting
# - Boiling
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page131.jpg
# Extracted information for images/page131.jpg:
# Based on the content of the image, here is the structured recipe information extracted:
#
# ### Recipe Title
# Corned Beef
#
# ### Ingredients
# - Corned beef (specific quantity not provided)
#
# ### Instructions
# 1. Should boil for four hours.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Main dish
#
# ### Relevant Tags/Metadata
# - Cooking time: 4 hours
# - Method: Boiling
#
# If you need further details or additional recipes, feel free to ask!
#
# Processing image images/page132.jpg
# Extracted information for images/page132.jpg:
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# Carrots
#
# ### Ingredients
# - Carrots
#
# ### Instructions
# 1. Wash, scrape, and boil the carrots for one hour.
# 2. For paring tomatoes, put them into very hot water, and the skin will come off easily.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Not specified
#
# ### Tags/Metadata
# - Cooking method: Boiling
# - Preparation: Washing and scraping
# - Additional tip: Skinning tomatoes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page133.jpg
# Extracted information for images/page133.jpg:
# I'm unable to view or analyze images directly. However, if you can provide the text or details from the recipe, I can help you structure that information into the desired format.
#
# Processing image images/page134.jpg
# Extracted information for images/page134.jpg:
# I'm unable to view or analyze images directly. However, if you can provide the text or details from the recipe, I can help you structure that information into the desired format.
#
# Processing image images/page135.jpg
# Extracted information for images/page135.jpg:
# I'm unable to analyze the content of the image as it appears to be blank. If you can provide the text or details from the recipe, I can help you structure that information.
#
# Processing image images/page136.jpg
# Extracted information for images/page136.jpg:
# I'm unable to analyze the content of the image directly. If you can provide the text or details from the recipe, I can help you structure that information into the desired format.

# %%
# Filter out non-recipe content based on key recipe-related terms
filtered_recipes = []

for recipe in extracted_recipes:
  # Check if the extracted content contains any key recipe-related terms
  if any(keyword in recipe["recipe_info"].lower() for keyword in ["ingredients",
                                                                  "instructions",
                                                                  "recipe title"]):
     # If it does, add it to the filtered list
    filtered_recipes.append(recipe)

  # Print a message for non-recipe content
  else:
    print(f"Skipping recipe: {recipe['image_path']}")
# Out:
# Skipping recipe: images/page2.jpg
# Skipping recipe: images/page3.jpg
# Skipping recipe: images/page4.jpg
# Skipping recipe: images/page5.jpg
# Skipping recipe: images/page7.jpg
# Skipping recipe: images/page8.jpg
# Skipping recipe: images/page10.jpg
# Skipping recipe: images/page12.jpg
# Skipping recipe: images/page20.jpg
# Skipping recipe: images/page22.jpg
# Skipping recipe: images/page106.jpg
# Skipping recipe: images/page107.jpg
# Skipping recipe: images/page108.jpg
# Skipping recipe: images/page113.jpg
# Skipping recipe: images/page133.jpg
# Skipping recipe: images/page134.jpg
# Skipping recipe: images/page135.jpg
# Skipping recipe: images/page136.jpg

# %%
# Define the output file path
output_file = "recipes_from_recipe_book.json"

# Write the filtered list to a json file
with open(output_file, "w") as json_file:
  json.dump(filtered_recipes, json_file, indent = 2)

# %% [markdown]
# ## Embeddings

# %%
# import libraries
import numpy as np

# %%
# Load the filtered recipes
with open("recipes_from_recipe_book.json", "r") as json_file:
  filtered_recipes = json.load(json_file)

# %%
# Generate embeddings for each recipe
recipe_texts = [recipe["recipe_info"] for recipe in filtered_recipes] # Extract the text content of each recipe

# Call the API to generate embeddings for the recipe texts
embedding_response = client.embeddings.create(
    input = recipe_texts,
    model = "text-embedding-3-large"
)

# Extract the embeddings
embeddings = [data.embedding for data in embedding_response.data]
embeddings
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert the embeddings to numpy array
embedding_matrix = np.array(embeddings)
embedding_matrix
# Out:
# array([[-0.00760287, -0.02689722, -0.01835082, ...,  0.00456719,
#         -0.02565286,  0.00255708],
#        [-0.01817757, -0.03411745, -0.02016824, ..., -0.0017264 ,
#         -0.02522483,  0.00685836],
#        [-0.01832132, -0.03103881, -0.0218346 , ..., -0.00241356,
#         -0.02523173,  0.00612283],
#        ...,
#        [-0.01796571, -0.03075307, -0.01259109, ...,  0.0044801 ,
#         -0.00267787,  0.00154841],
#        [-0.01096358, -0.02817693, -0.01316821, ...,  0.00346915,
#          0.00022055, -0.00669666],
#        [-0.02556907, -0.03703867, -0.01312876, ..., -0.00506356,
#         -0.01241277,  0.01063657]])

# %%
# Verify the embedding matrix
print(f"Generated embeddings for {len(filtered_recipes)} recipes.")
print(f"Each embedding is of size {len(embeddings[0])}")
# Out:
# Generated embeddings for 118 recipes.
# Each embedding is of size 3072

# %% [markdown]
# ## Retrieval System

# %%
# Install the faiss-cpu library
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 31.3 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
# Import the faiss library
import faiss

# %%
# Print the embedding matrix shape
print(f"Embedding matrix shape: {embedding_matrix.shape}")
# Out:
# Embedding matrix shape: (118, 3072)

# %%
# Initialize the FAISS index for similarity search
index = faiss.IndexFlatL2(embedding_matrix.shape[1]) # Create a FAISS index with L2 distance metric
index.add(embedding_matrix) # Add the embeddings to the index

# %%
# Save the FAISS index to a file
faiss.write_index(index, "recipes_as_index.index")

# %%
# Save the metadata for each recipe
metadata = [{'recipe_info': recipe['recipe_info'], # Include recipe information
             'image_path': recipe['image_path']} for recipe in filtered_recipes] # Include image path

# Write metadata to a JSON file with indentation
with open("recipe_metadata.json", "w") as json_file:
  json.dump(metadata, json_file, indent = 2)

# %% [markdown]
# ### Simple retriever demo

# %%
# Generate the embeddings for the query
query = "How to make bread?"
k = 5 # Number of top results to retrieve
query_embedding = client.embeddings.create(
    input = [query],
    model = "text-embedding-3-large"
).data[0].embedding
print(f"The query embedding is {query_embedding}\n")
query_vector = np.array(query_embedding).reshape(1, -1)  # Convert embedding to a 2D numpy array for FAISS
print(f"The query vector is {query_vector}\n")

# Search the FAISS index for the nearest neighbors
distances, indices = index.search(query_vector, min(k, len(metadata)))
print(f"The distances are {distances}\n")
print(f"The indices are {indices}\n")

# Store the indices and distances
stored_indices = indices[0].tolist()
stored_distances = distances[0].tolist()
print(f"The stored indices are {stored_indices}\n")
print(f"The stored distances are {stored_distances}\n")

# Print the metadata content for the top results
print("The metadata content is")
for i, dist in zip(stored_indices, stored_distances):
  if 0 <=i < len(metadata):
    print(f"Distance: {dist}, Metadata: {metadata[i]['recipe_info']}")

# Return the results
results = [(metadata[i]['recipe_info'], dist) for i, dist in zip(stored_indices, stored_distances) if 0 <= i < len(metadata)]
results # Output the results as a list of tuples containing recipe info and distance
# Out:
# The query embedding is [-0.019720381125807762, -0.028134725987911224, -0.022066915407776833, 0.016603518277406693, -0.04792621359229088, -0.04887430742383003, 0.038018617779016495, 0.017954552546143532, 0.0015480617294088006, 0.004168656188994646, -0.004832322709262371, -0.013889594934880733, -0.012917797081172466, -0.0015850967029109597, 0.038018617779016495, -0.0238090418279171, 0.017018308863043785, -0.016674624755978584, -0.0072233001701533794, 0.002310981974005699, -0.031856000423431396, 0.02015887387096882, 0.01501545775681734, -0.007821785286068916, 0.006275205407291651, 0.01784789189696312, 0.003410179866477847, -0.011229002848267555, -0.03960667923092842, 0.042285047471523285, -0.0036649806424975395, 0.023678677156567574, -0.034676581621170044, -0.02115437388420105, -0.015904298052191734, 0.011306035332381725, -0.01473102904856205, 0.005285630933940411, 0.00849730335175991, 0.019412249326705933, -0.01242004707455635, 0.007833636365830898, 0.00040108870598487556, -0.008254353888332844, -0.01242004707455635, 0.016473153606057167, 0.06238466501235962, 0.019755933433771133, -0.015513207763433456, -0.011489728465676308, 0.04603002220392227, 0.008455824106931686, 0.038943011313676834, 0.0010103139793500304, -0.027139225974678993, 0.06679330766201019, 0.012242279015481472, -0.04579300060868263, 0.0012480784207582474, -0.010849764570593834, 0.018973754718899727, -0.014221427962183952, -0.026665177196264267, 0.029509464278817177, 0.014138469472527504, -0.025527464225888252, -0.00322056096047163, 0.013581464067101479, 0.006897392682731152, 0.027826594188809395, 0.011548984795808792, -0.006316684186458588, 0.0031968585681170225, 0.026357047259807587, 0.006583336275070906, 0.006719624623656273, 0.002266540192067623, -0.048826903104782104, 0.030931606888771057, 0.04211913049221039, -0.025645975023508072, -0.010452750138938427, -0.00634631235152483, -0.01646130345761776, -0.021261034533381462, 0.04088660702109337, 0.006861838977783918, -0.04650406911969185, 0.011110491119325161, -0.027139225974678993, 0.07015904784202576, -0.010197949595749378, 0.03327814117074013, 0.002349498448893428, 0.03835045173764229, 0.0030664955265820026, 0.02600151114165783, -0.009125416167080402, 0.005063421092927456, -0.014505856670439243, -0.05589021369814873, -0.00197026040405035, 0.002785029588267207, -0.01476658321917057, -0.02550376206636429, 0.04429974779486656, 0.027589570730924606, 0.03346776217222214, -0.015501356683671474, -0.0904482826590538, 0.008918020874261856, 0.009741677902638912, 0.006227800622582436, 0.01803751103579998, -0.019056713208556175, -0.01159638911485672, 0.0052767423912882805, -0.009955000132322311, 0.03806602209806442, -0.002854655496776104, 0.019258184358477592, 0.01949520781636238, 0.02411717176437378, 0.03797121345996857, -0.026902202516794205, -0.004459010437130928, -0.006512228865176439, -0.020123321563005447, 0.001433253288269043, 0.01827453449368477, -0.006879616063088179, -0.004447158891707659, -0.03235374763607979, 0.02915392816066742, -0.0029005787800997496, -0.01819157600402832, 0.023086117580533028, 0.013261482119560242, 0.00018443414592184126, 0.004076809622347355, 0.0028620625380426645, 0.014138469472527504, -5.8098608860746026e-05, -0.010126842185854912, 0.0011503061978146434, 0.027779189869761467, -0.006932946387678385, -0.015062863007187843, -0.006956648547202349, 0.030410153791308403, -0.05081790313124657, 0.0016399084124714136, -0.0003744235436897725, -0.019779635593295097, -0.022789837792515755, -0.010861615650355816, -0.006577410735189915, 0.0008273611892946064, 0.03045755811035633, 0.03638315200805664, 0.0027079968713223934, -0.029604272916913033, 0.01753976196050644, 0.01949520781636238, -0.03161897510290146, 0.018523409962654114, -0.03131084516644478, 0.005377477500587702, -0.05133935436606407, 0.014494005590677261, -0.03787640482187271, 0.010820136405527592, 0.00021165484213270247, 0.005113788414746523, -0.02096475474536419, 0.0189263503998518, 0.005854487884789705, -0.02953316643834114, 0.0296516772 ...
#
# The query vector is [[-0.01972038 -0.02813473 -0.02206692 ...  0.00189471  0.01315482
#    0.00581301]]
#
# The distances are [[1.1378558 1.1652403 1.1838977 1.1895697 1.1977985]]
#
# The indices are [[ 12 109  20   4  19]]
#
# The stored indices are [12, 109, 20, 4, 19]
#
# The stored distances are [1.1378557682037354, 1.1652402877807617, 1.1838977336883545, 1.1895697116851807, 1.197798490524292]
#
# The metadata content is
# Distance: 1.1378557682037354, Metadata: Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Breads
#
# ### Ingredients
# #### Bannocks
# - 1 Cupful of Thick Sour Milk
# - ½ Cupful of Sugar
# - 2 Cupfuls of Flour
# - ½ Cupful of Indian Meal
# - 1 Teaspoonful of Soda
# - A pinch of Salt
#
# #### Boston Brown Bread
# - 1 Cupful of Rye Meal
# - 1 Cupful of Graham Meal
# - 1 Cupful of Flour
# - 1 Cupful of Sour Milk
# - ½ Cupful of Molasses
# - 1 Teaspoonful of Salt
# - 1 Heaping Teaspoonful of Soda
# - Stir the meals and salt together. Beat the soda into the molasses until it foams; add sour milk, mix well, and pour into a tin pan which has been well greased, if you have no brown-bread steamer.
#
# ### Step-by-Step Instructions
# 1. For Bannocks, make the mixture and drop from a spoon.
# 2. Drop mixture, size of a walnut, into boiling fat. Serve warm with maple syrup.
# 3. For Boston Brown Bread, stir the meals and salt together.
# 4. Beat the soda into the molasses until it foams.
# 5. Add sour milk, mix well, and pour into a greased tin pan.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Breads
#
# ### Relevant Tags/Metadata
# - Homemade
# - Breakfast
# - Comfort Food
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# Distance: 1.1652402877807617, Metadata: It seems that the image contains text related to various tips and instructions rather than a specific recipe. However, I can help you structure the information based on the content provided. Here’s a structured format:
#
# ### Recipe Information
#
# - **Title**: Not specified (contains various tips)
#
# - **Ingredients**:
#   - Graham bread
#   - Gingerbread
#   - Brown bread
#   - Cracker boxes
#   - Doughnuts
#   - Biscuit
#   - Butter (optional)
#
# - **Instructions**:
#   1. Stand while shaking the mixture.
#   2. Rinse in clear, warm water.
#   3. Dry on a clean cloth in the sunshine.
#   4. Set the milk on the back of the stove to thicken.
#   5. Strain through a cloth.
#   6. Put in a small salt, a small piece of butter, and a little sugar if desired.
#   7. Press into pans and serve.
#
# - **Cuisine Type**: Not specified
#
# - **Dish Type**: Not specified
#
# - **Tags/Metadata**:
#   - Tips for using sour milk
#   - Kitchen advice
#   - Economic cooking
#
# If you have a specific recipe in mind or need further assistance, feel free to ask!
# Distance: 1.1838977336883545, Metadata: Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Nut Bread
#
# ### Ingredients
# - 2½ Cups of Flour
# - 3 Teaspoons of Baking Powder
# - ¾ Cup of Walnuts (or nut meats), chopped
# - ½ Cup of Sugar
# - 2¾ Cups of Rolled Oats
# - 1½ Cups of Molasses
# - 1 Yeast Cake
# - Water
#
# ### Instructions
# 1. Mix the flour, baking powder, and sugar together.
# 2. Add the chopped walnuts.
# 3. Stir in the rolled oats and molasses.
# 4. Dissolve the yeast cake in warm water and add to the mixture.
# 5. Mix well and let it rise for about one hour.
# 6. After rising, stir the mixture again.
# 7. Pour into greased loaf pans and let rise again.
# 8. Bake in a moderate oven until done.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread
#
# ### Tags/Metadata
# - Baking
# - Quick Bread
# - Nut Bread
# - Oatmeal Bread
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# Distance: 1.1895697116851807, Metadata: Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# - Breads
#
# ### List of Ingredients
# - Not provided in the image.
#
# ### Step-by-Step Instructions
# - Not provided in the image.
#
# ### Cuisine Type
# - Not specified in the image.
#
# ### Dish Type
# - Breads
#
# ### Relevant Tags or Metadata
# - Bannocks
# - Boston Brown Bread
# - Brown Bread (Baked)
# - Coffee Cakes
# - Corn Meal Gems
# - Cream of Tartar Biscuits
# - Crullers
# - Delicious Drop Biscuits
# - Doughnuts
# - Fried Bread
# - Graham Toast
# - Huckleberry Cake
# - Quick Graham Bread
# - Graham Bread (Raised Over Night)
# - Graham Muffins
# - Sweet Milk Griddle Cakes
# - Jenny Lind Tea Cake
# - Real Johnny Cakes
# - New England Buns
# - Nut Bread
# - Oatmeal Bread
# - Parker House Rolls
# - Popovers
# - Rye Muffins
# - Breakfast Sally Lunn
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# Distance: 1.197798490524292, Metadata: Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Real Johnny Cake
#
# ### Ingredients
# - 2 Cups of Flour
# - 1 Cupful of Yeast
# - 1 Cupful of Sugar
# - ½ Teaspoon of Salt
# - 1 Teaspoon of Cream of Tartar
# - ½ Teaspoon of Baking Powder
# - Enough milk or water to make a thin batter
#
# ### Step-by-Step Instructions
# 1. Dissolve the yeast in a half-cup of cold water.
# 2. Scale the milk and water, and mix with the flour and sugar.
# 3. Let the mixture rise to twice its volume.
# 4. When light and frothy, add the rest of the ingredients.
# 5. Mix in a little flour, using a cookie cutter to cut out the dough.
# 6. Let rise again.
# 7. Bake in a moderate oven.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Baked Good
#
# ### Relevant Tags/Metadata
# - Baking
# - Yeast Bread
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# [('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nBreads\n\n### Ingredients\n#### Bannocks\n- 1 Cupful of Thick Sour Milk\n- ½ Cupful of Sugar\n- 2 Cupfuls of Flour\n- ½ Cupful of Indian Meal\n- 1 Teaspoonful of Soda\n- A pinch of Salt\n\n#### Boston Brown Bread\n- 1 Cupful of Rye Meal\n- 1 Cupful of Graham Meal\n- 1 Cupful of Flour\n- 1 Cupful of Sour Milk\n- ½ Cupful of Molasses\n- 1 Teaspoonful of Salt\n- 1 Heaping Teaspoonful of Soda\n- Stir the meals and salt together. Beat the soda into the molasses until it foams; add sour milk, mix well, and pour into a tin pan which has been well greased, if you have no brown-bread steamer.\n\n### Step-by-Step Instructions\n1. For Bannocks, make the mixture and drop from a spoon.\n2. Drop mixture, size of a walnut, into boiling fat. Serve warm with maple syrup.\n3. For Boston Brown Bread, stir the meals and salt together.\n4. Beat the soda into the molasses until it foams.\n5. Add sour milk, mix well, and pour into a greased tin pan.\n\n### Cuisine Type\nTraditional American\n\n### Dish Type\nBreads\n\n### Relevant Tags/Metadata\n- Homemade\n- Breakfast\n- Comfort Food\n- Traditional Recipes\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.1378557682037354),
#  ('It seems that the image contains text related to various tips and instructions rather than a specific recipe. However, I can help you structure the information based on the content provided. Here’s a structured format:\n\n### Recipe Information\n\n- **Title**: Not specified (contains various tips)\n  \n- **Ingredients**: \n  - Graham bread\n  - Gingerbread\n  - Brown bread\n  - Cracker boxes\n  - Doughnuts\n  - Biscuit\n  - Butter (optional)\n\n- **Instructions**:\n  1. Stand while shaking the mixture.\n  2. Rinse in clear, warm water.\n  3. Dry on a clean cloth in the sunshine.\n  4. Set the milk on the back of the stove to thicken.\n  5. Strain through a cloth.\n  6. Put in a small salt, a small piece of butter, and a little sugar if desired.\n  7. Press into pans and serve.\n\n- **Cuisine Type**: Not specified\n\n- **Dish Type**: Not specified\n\n- **Tags/Metadata**: \n  - Tips for using sour milk\n  - Kitchen advice\n  - Economic cooking\n\nIf you have a specific recipe in mind or need further assistance, feel free to ask!',
#   1.1652402877807617),
#  ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nNut Bread\n\n### Ingredients\n- 2½ Cups of Flour\n- 3 Teaspoons of Baking Powder\n- ¾ Cup of Walnuts (or nut meats), chopped\n- ½ Cup of Sugar\n- 2¾ Cups of Rolled Oats\n- 1½ Cups of Molasses\n- 1 Yeast Cake\n- Water\n\n### Instructions\n1. Mix the flour, baking powder, and sugar together.\n2. Add the chopped walnuts.\n3. Stir in the rolled oats and molasses.\n4. Dissolve the yeast cake in warm water and add to the mixture.\n5. Mix well and let it rise for about one hour.\n6. After rising, stir the mixture again.\n7. Pour into greased loaf pans and let rise again.\n8. Bake in a moderate oven until done.\n\n### Cuisine Type\nAmerican\n\n### Dish Type\nBread\n\n### Tags/Metadata\n- Baking\n- Quick Bread\n- Nut Bread\n- Oatmeal Bread\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.1838977336883545),
#  ('Based on the content of the image, here is the structured information extracted:\n\n### Recipe Title\n- Breads\n\n### List of Ingredients\n- Not provided in the image.\n\n### Step-by-Step Instructions\n- Not provided in the image.\n\n### Cuisine Type\n- Not specified in the image.\n\n### Dish Type\n- Breads\n\n### Relevant Tags or Metadata\n- Bannocks\n- Boston Brown Bread\n- Brown Bread (Baked)\n- Coffee Cakes\n- Corn Meal Gems\n- Cream of Tartar Biscuits\n- Crullers\n- Delicious Drop Biscuits\n- Doughnuts\n- Fried Bread\n- Graham Toast\n- Huckleberry Cake\n- Quick Graham Bread\n- Graham Bread (Raised Over Night)\n- Graham Muffins\n- Sweet Milk Griddle Cakes\n- Jenny Lind Tea Cake\n- Real Johnny Cakes\n- New England Buns\n- Nut Bread\n- Oatmeal Bread\n- Parker House Rolls\n- Popovers\n- Rye Muffins\n- Breakfast Sally Lunn\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.1895697116851807),
#  ('Here’s the structured information extracted from the recipe:\n\n### Recipe Title\nReal Johnny Cake\n\n### Ingredients\n- 2 Cups of Flour\n- 1 Cupful of Yeast\n- 1 Cupful of Sugar\n- ½ Teaspoon of Salt\n- 1 Teaspoon of Cream of Tartar\n- ½ Teaspoon of Baking Powder\n- Enough milk or water to make a thin batter\n\n### Step-by-Step Instructions\n1. Dissolve the yeast in a half-cup of cold water.\n2. Scale the milk and water, and mix with the flour and sugar.\n3. Let the mixture rise to twice its volume.\n4. When light and frothy, add the rest of the ingredients.\n5. Mix in a little flour, using a cookie cutter to cut out the dough.\n6. Let rise again.\n7. Bake in a moderate oven.\n\n### Cuisine Type\nAmerican\n\n### Dish Type\nBaked Good\n\n### Relevant Tags/Metadata\n- Baking\n- Yeast Bread\n- Traditional Recipe\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.197798490524292)]

# %%
# Define a function to query the embeddings
def query_embeddings(query, index, metadata, k = 5):
  # Generate the embeddings for the query
  query_embedding = client.embeddings.create(
      input = [query],
      model = "text-embedding-3-large"
  ).data[0].embedding
  print(f"The query embedding is {query_embedding}\n")
  query_vector = np.array(query_embedding).reshape(1, -1)
  print(f"The query vector is {query_vector}\n")

  # Search faiss index
  distances, indices = index.search(query_vector, min(k, len(metadata)))

  # Store the indices and distances
  stored_indices = indices[0].tolist()
  stored_distances = distances[0].tolist()
  print(f"The stored indices are {stored_indices}\n")
  print(f"The stored distances are {stored_distances}\n")

  # Return the results
  results = [(
      metadata[i]['recipe_info'], dist) for i, dist in zip(
          stored_indices, stored_distances) if 0 <= i < len(metadata)]
  return results

# %%
# Test the retrieval system
query = "chocolate query"
results = query_embeddings(query, index, metadata)
print(f"The results are {results}")
# Out:
# The query embedding is [-0.014626344665884972, -0.005924540106207132, -0.01682029664516449, -0.006895276717841625, -0.0328744500875473, 0.009994668886065483, 0.023471800610423088, 0.0519583486020565, -0.015261894091963768, 0.046490881592035294, 0.005841831676661968, -0.01802174560725689, -0.049799222499132156, 0.0076222410425543785, -0.025787638500332832, 0.014669875614345074, -0.013781847432255745, -0.015174832195043564, -0.020424645394086838, -0.03021036647260189, 0.02106890082359314, -0.01762126199901104, -0.005419583059847355, 0.02754628285765648, 0.023367326706647873, 0.04920720309019089, -0.011326710693538189, -0.00455767335370183, -0.038620512932538986, 0.012397568672895432, 0.01265004649758339, 0.018718238919973373, 0.027911940589547157, -0.021591270342469215, -0.02025052160024643, 0.009750896133482456, 0.01760384999215603, -0.038829460740089417, 0.015897443518042564, -0.009315588511526585, 0.02211363986134529, -0.03590419515967369, -0.021643508225679398, -0.0011677134316414595, 0.0006845216266810894, 0.003856827737763524, 0.030750147998332977, 0.007805070374161005, 0.014208449050784111, -0.022984255105257034, 0.027720404788851738, 0.014199743047356606, 0.00760482857003808, -0.03278739005327225, -0.025857288390398026, -0.009141465649008751, 0.041650258004665375, 0.02267083339393139, -0.0009092492982745171, 0.015270600095391273, -0.013520662672817707, -0.030488964170217514, 0.01943214423954487, 0.03160335123538971, -0.026466719806194305, 0.05122702941298485, -0.012075440026819706, 0.0482669360935688, 0.034145548939704895, 0.0249344352632761, -0.005349933635443449, -0.026989087462425232, -0.027720404788851738, 0.03019295446574688, -0.007561297621577978, 0.04276464506983757, -0.005672061815857887, -0.006642797961831093, 0.009263351559638977, 0.01689865253865719, -0.003693587379530072, 0.009951137937605381, 0.005998542532324791, 0.013459719717502594, 0.05369957908987999, -0.016472050920128822, -0.03508581593632698, -0.07717137783765793, -0.012441098690032959, 0.01845705322921276, -0.010786929167807102, -0.02025052160024643, 0.013303008861839771, -0.035764895379543304, 0.013860202394425869, -0.006120428908616304, 0.02674531564116478, -0.012414980679750443, -0.03956077992916107, 0.014173624105751514, -0.04579439014196396, -0.04189402982592583, -0.02411605603992939, -0.03726235404610634, 0.03386695310473442, -0.03813296929001808, 0.006320670247077942, -0.015949681401252747, -0.026849789544939995, -0.015775557607412338, 0.005214988254010677, 0.014147506095468998, -0.045898862183094025, -0.008166375569999218, -0.008915104903280735, -0.031498879194259644, -0.013825378380715847, 0.008253437466919422, 0.016959594562649727, -0.0168377086520195, 0.006277139764279127, 0.009559361264109612, -0.01460893265902996, -0.024847373366355896, -0.0005444069392979145, -0.018561527132987976, -0.006081250961869955, 0.00857121217995882, -0.00035151111660525203, 0.0077745988965034485, -0.01807398349046707, -0.030332252383232117, -0.04050104320049286, -0.008558153174817562, 0.0625450387597084, 0.007970486767590046, 0.04360043630003929, 0.06630609929561615, 0.005389111582189798, 0.04046621918678284, -0.012798051349818707, -0.025700576603412628, -0.011944848112761974, -0.024377241730690002, -0.019571442157030106, 0.005393464583903551, 0.010691161267459393, 0.012092852964997292, 0.004239898640662432, 0.02188728004693985, -0.012475923635065556, -0.015244482085108757, -0.024481715634465218, 0.013616430573165417, 0.009054403752088547, 0.041058238595724106, -0.0060899569652974606, -0.012171207927167416, -0.02796417847275734, -0.008074960671365261, 0.024446889758110046, -0.026484131813049316, 0.05742581561207771, -0.0016019330359995365, -0.0022287762258201838, -0.00861039012670517, 0.03503357619047165, -0.003948242403566837, -0.06710705906152725, 0.03604349121451378, -0.0021036253310739994, 0.014556695707142353, -0.007805070374161005, -0.008331792429089546, -0.03503357619047165, -0.0016193452756851912, 0.03062826208770275, 0.0015649318229407072, -0.01118741 ...
#
# The query vector is [[-1.46263447e-02 -5.92454011e-03 -1.68202966e-02 ...  1.37383165e-02
#   -1.19883791e-02  9.25029235e-05]]
#
# The stored indices are [86, 32, 87, 10, 81]
#
# The stored distances are [1.296700119972229, 1.3190944194793701, 1.321857213973999, 1.3591651916503906, 1.363250732421875]
#
# The results are [('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nSauces\n\n### Ingredients\n#### Chocolate Sauce\n- 1 Tablespoon of Butter\n- 1 Cup of Sugar\n- 2 Tablespoons of Boiling Cocoa\n- 1 Cup of Water\n\n#### Cold Sauce\n- 1 Cup of Butter\n- 1.5 Cups of Sugar\n- 1 Nutmeg (for grating)\n\n#### Cranberry Sauce\n- 1 Cup of Cranberries\n\n#### Cream Mustard\n- ½ Cup of Vinegar\n- 1 Teaspoon of Salt\n- ½ Cup of Sweet Cream\n- 1 Tablespoon of Mustard\n\n### Instructions\n#### Chocolate Sauce\n1. Put the butter into an agate dish on the stove.\n2. When melted, stir in the cocoa and sugar dry; add boiling water and stir until smooth.\n3. Add vanilla to taste.\n\n#### Cold Sauce\n1. Cream together butter and sugar.\n2. Grate a little nutmeg over the top.\n\n#### Cranberry Sauce\n1. Pick over and wash one cup of cranberries.\n2. Cover with cold water and cook until tender.\n3. Remove from the fire, rub through a colander, and sweeten to taste.\n\n#### Cream Mustard\n1. Put the vinegar on the stove and let it come to a boil.\n\n### Cuisine Type\nGeneral Sauces\n\n### Dish Type\nSauces\n\n### Tags/Metadata\n- Sauces\n- Dessert\n- Condiments\n- Cooking Techniques\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.', 1.296700119972229), ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nOld-Fashioned Candies\n\n### Ingredients\n#### Chocolate Taffy\n- 1½ Cups of Molasses\n- 1½ Cups of Sugar\n- ½ Cup of Milk\n- 2 Squares of Chocolate\n- 1 Small Teaspoon of Butter\n- 1½ Cups of Flour\n\n#### Molasses Candy\n- 2 Cups of Molasses\n- ¼ Cup of Sugar\n- 2 Teaspoons of Vinegar\n- ¼ Teaspoon of Soda\n- 1 Small Teaspoon of Butter\n\n### Step-by-Step Instructions\n#### Chocolate Taffy\n1. Stir the sugar, flour, and grated chocolate into the molasses and milk.\n2. When hot, add the butter. Boil until it strings.\n3. Pour into buttered tin. When nearly cold, mark into squares.\n\n#### Molasses Candy\n1. Put the molasses, vinegar, and butter into a saucepan.\n2. Boil until it strings when dropped from a spoon. \n3. When it is brittle when tested in cold water, stir the soda in briskly and pour into a buttered tin.\n4. When nearly cold, cut into small pieces or sticks and lay on a buttered platter.\n\n### Cuisine Type\nAmerican\n\n### Dish Type\nCandy\n\n### Tags/Metadata\n- Old-fashioned\n- Candy recipes\n- Sweet treats\n- Homemade candy\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.', 1.3190944194793701), ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nEgg Sauce for Chocolate Pudding\n\n### Ingredients\n- 2 Cups of Sugar\n- 1 Cupful of Butter\n- 1 Cupful of Boiling Milk\n- 1 Cupful of Water\n- 1 Cupful of Cornstarch\n- Flavoring (not specified)\n\n### Step-by-Step Instructions\n1. Cream the butter and sugar together.\n2. Boil the water and add it to the mixture.\n3. Stir in the cornstarch mixed with a little water.\n4. Pour the mixture into the boiling milk and flavor.\n5. Cook until thickened.\n6. When cold, it is ready for use.\n\n### Cuisine Type\nNot specified\n\n### Dish Type\nSauce\n\n### Relevant Tags/Metadata\n- Dessert\n- Pudding Sauce\n- Sweet Sauce\n\n---\n\n### Recipe Title\nPudding Sauce\n\n### Ingredients\n- 1 Cup of Sugar\n- 3 Heaping Teaspoons of Cornstarch\n- 1 Pint of Water\n- Flavoring (not specified)\n\n### Step-by-Step Instructions\n1. Mix the sugar and cornstarch together.\n2. Add the mixture to the pint of boiling water.\n3. Stir until thickened.\n4. Add flavoring as desired.\n\n### Cuisine Type\nNot specified\n\n### Dish Type\nSauce\n\n### Relevant Tags/Metadata\n- Dessert\n- Pudding Sauce\n- Sweet Sauce\n\n---\n\n### Recipe Title\nSalad Dressing\n\n### Ingredients\n- 1 Egg\n- 2 Tablespoons of Sugar\n- 1 Tablespoon of Flour\n- ½ Cupful of Milk\n- ½ Cupful of Vinegar\n- ½ Cupful of Walnut\n- ½ Teaspoon of Mustard\n- 1 Te ...

# %%
# Combine the results into a single string
def combined_retrived_content(results):
  combined_content = "\n\n".join([result[0] for result in results]) # Join the recipe information with double newlines
  return combined_content

# Get the combined content from results
combined_content = combined_retrived_content(results)
print(f"The combined content is {combined_content}")
# Out:
# The combined content is Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Sauces
#
# ### Ingredients
# #### Chocolate Sauce
# - 1 Tablespoon of Butter
# - 1 Cup of Sugar
# - 2 Tablespoons of Boiling Cocoa
# - 1 Cup of Water
#
# #### Cold Sauce
# - 1 Cup of Butter
# - 1.5 Cups of Sugar
# - 1 Nutmeg (for grating)
#
# #### Cranberry Sauce
# - 1 Cup of Cranberries
#
# #### Cream Mustard
# - ½ Cup of Vinegar
# - 1 Teaspoon of Salt
# - ½ Cup of Sweet Cream
# - 1 Tablespoon of Mustard
#
# ### Instructions
# #### Chocolate Sauce
# 1. Put the butter into an agate dish on the stove.
# 2. When melted, stir in the cocoa and sugar dry; add boiling water and stir until smooth.
# 3. Add vanilla to taste.
#
# #### Cold Sauce
# 1. Cream together butter and sugar.
# 2. Grate a little nutmeg over the top.
#
# #### Cranberry Sauce
# 1. Pick over and wash one cup of cranberries.
# 2. Cover with cold water and cook until tender.
# 3. Remove from the fire, rub through a colander, and sweeten to taste.
#
# #### Cream Mustard
# 1. Put the vinegar on the stove and let it come to a boil.
#
# ### Cuisine Type
# General Sauces
#
# ### Dish Type
# Sauces
#
# ### Tags/Metadata
# - Sauces
# - Dessert
# - Condiments
# - Cooking Techniques
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Old-Fashioned Candies
#
# ### Ingredients
# #### Chocolate Taffy
# - 1½ Cups of Molasses
# - 1½ Cups of Sugar
# - ½ Cup of Milk
# - 2 Squares of Chocolate
# - 1 Small Teaspoon of Butter
# - 1½ Cups of Flour
#
# #### Molasses Candy
# - 2 Cups of Molasses
# - ¼ Cup of Sugar
# - 2 Teaspoons of Vinegar
# - ¼ Teaspoon of Soda
# - 1 Small Teaspoon of Butter
#
# ### Step-by-Step Instructions
# #### Chocolate Taffy
# 1. Stir the sugar, flour, and grated chocolate into the molasses and milk.
# 2. When hot, add the butter. Boil until it strings.
# 3. Pour into buttered tin. When nearly cold, mark into squares.
#
# #### Molasses Candy
# 1. Put the molasses, vinegar, and butter into a saucepan.
# 2. Boil until it strings when dropped from a spoon.
# 3. When it is brittle when tested in cold water, stir the soda in briskly and pour into a buttered tin.
# 4. When nearly cold, cut into small pieces or sticks and lay on a buttered platter.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Candy
#
# ### Tags/Metadata
# - Old-fashioned
# - Candy recipes
# - Sweet treats
# - Homemade candy
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Egg Sauce for Chocolate Pudding
#
# ### Ingredients
# - 2 Cups of Sugar
# - 1 Cupful of Butter
# - 1 Cupful of Boiling Milk
# - 1 Cupful of Water
# - 1 Cupful of Cornstarch
# - Flavoring (not specified)
#
# ### Step-by-Step Instructions
# 1. Cream the butter and sugar together.
# 2. Boil the water and add it to the mixture.
# 3. Stir in the cornstarch mixed with a little water.
# 4. Pour the mixture into the boiling milk and flavor.
# 5. Cook until thickened.
# 6. When cold, it is ready for use.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Sauce
#
# ### Relevant Tags/Metadata
# - Dessert
# - Pudding Sauce
# - Sweet Sauce
#
# ---
#
# ### Recipe Title
# Pudding Sauce
#
# ### Ingredients
# - 1 Cup of Sugar
# - 3 Heaping Teaspoons of Cornstarch
# - 1 Pint of Water
# - Flavoring (not specified)
#
# ### Step-by-Step Instructions
# 1. Mix the sugar and cornstarch together.
# 2. Add the mixture to the pint of boiling water.
# 3. Stir until thickened.
# 4. Add flavoring as desired.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Sauce
#
# ### Relevant Tags/Metadata
# - Dessert
# - Pudding Sauce
# - Sweet Sauce
#
# ---
#
# ### Recipe Title
# Salad Dressing
#
# ### Ingredients
# - 1 Egg
# - 2 Tablespoons of Sugar
# - 1 Tablespoon of Flour
# - ½ Cupful of Milk
# - ½ Cupful of Vinegar
# - ½ Cupful of Walnut
# - ½ Teaspoon of Mustard
# - 1 Teaspoon of Salt
#
# ### Step-by-Step Instructions
# 1. Beat the egg.
# 2. Mix in the sugar, flour, and milk.
# 3. Add vinegar and mustard.
# 4. Stir until well combined.
# 5. Season with salt.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Dressing
#
# ### Relevant Tags/Metadata
# - Salad Dressing
# - Condiment
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# - Sauces
#
# ### List of Ingredients
# - Chocolate Sauce
# - Cold Sauce
# - Cranberry Sauce
# - Cream Mustard
# - Egg Sauce for Chocolate Pudding
# - Pudding Sauce
# - Sauce for Graham Pudding
#
# ### Step-by-Step Instructions
# - Not provided in the image.
#
# ### Cuisine Type
# - Not specified in the image.
#
# ### Dish Type
# - Sauces
#
# ### Relevant Tags or Metadata
# - Sauces
# - Puddings
# - Soups
# - Vegetables
#
# ### Additional Notes
# - The image includes a table of contents with references to various recipes, but specific instructions or ingredient details are not included.
#
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Puddings
#
# ### Ingredients
# #### Bread Pudding
# - 1 Pint of Stale Bread
# - 1 Cupful of Raisins
# - 1 Cupful of Milk
# - 1 Cupful of Sugar
# - 1 Egg
# - 1 Teaspoon of Cinnamon
# - ½ Teaspoon of Salt
#
# #### Steamed Chocolate Pudding
# - 1 Butter size of a Walnut
# - ½ Cupful of Sugar
# - ½ Cupful of Milk
# - 1 Egg
# - 1 Teaspoon of Baking Powder
# - Salt to Taste
# - ½ Cupful of Cocoa
# - 2 Tablespoons of Chocolate
#
# ### Instructions
# 1. For Bread Pudding: Pour hot water over the stale bread and let soak until soft. Then add other ingredients and bake for three hours in a moderate oven. If eaten cold, serve with hot sauce. If eaten hot, serve with cold sauce.
# 2. For Steamed Chocolate Pudding: Cream together the butter and sugar, then add egg and milk; then the cocoa, flour, salt, and flavoring. Steam for an hour and a half, and serve hot.
#
# ### Cuisine Type
# Dessert
#
# ### Dish Type
# Pudding
#
# ### Tags/Metadata
# - Bread Pudding
# - Chocolate Pudding
# - Steamed Dessert
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.

# %% [markdown]
# ## Generative System

# %%
# Define the system prompt
system_prompt3 = f"""
You are highly experienced and expert chef specialized in providing cooking advice.
Your main task is to provide information precise and accurate on the combined content.
You answer diretly to the query using only information from the provided {combined_content}.
If you don't know the answer, just say that you don't know.
Your goal is to help the user and answer the {query}
"""

# %%
# Define function to retrieve a response from the API
def generate_response(query, combined_content, system_prompt):
  response = client.chat.completions.create(
      model = model,
      messages = [
          {"role": "system", "content": system_prompt}, # Provide system prompt for guidance
          {"role": "user", "content": query}, # Provide the query as user input
          {"role": "assistant", "content": combined_content} # Provide the combined content from the results
      ],
      temperature = 0, # Set temperature to 0 for deterministic output
  )
  return response

# %%
# Define a function to get the GPT response and display it in Markdown
def get_gpt_response():
  gpt_response = response.choices[0].message.content # Extract the response content from the API response
  return display(Markdown(gpt_response)) # Display the response as Markdown

# %%
# Get the results from the API
query = "How to make bread?"
combined_content = combined_retrived_content(results)
response = generate_response(query, combined_content, system_prompt3)

# %%
# Display the outcome
get_gpt_response()
# Out:
# I'm sorry, but I don't have a recipe for making bread. If you have any other questions or need information on a different recipe, feel free to ask!

# %%
# Get the results
query = "Get me the best chocolate cake recipe"
combined_content = combined_retrived_content(results)
response = generate_response(query, combined_content, system_prompt3)

# Display the outcome
get_gpt_response()
# Out:
# I don't have a specific chocolate cake recipe available. However, I can provide you with a chocolate sauce recipe that you can use as a topping for cakes or desserts. Here it is:
#
# ### Chocolate Sauce Recipe
#
# #### Ingredients
# - 1 Tablespoon of Butter
# - 1 Cup of Sugar
# - 2 Tablespoons of Boiling Cocoa
# - 1 Cup of Water
#
# #### Instructions
# 1. Put the butter into an agate dish on the stove.
# 2. When melted, stir in the cocoa and sugar dry; add boiling water and stir until smooth.
# 3. Add vanilla to taste.
#
# This chocolate sauce can enhance the flavor of your chocolate cake or any dessert you choose! If you need more specific cake recipes, please let me know!

# %% [markdown]
# ## RAG System

# %%
# Build the function for Retrieval-Augmented Generation (RAG)
def rag_system(query, index, metadata, system_prompt, k = 5):
  # Retrieval System: Retrieve relevant results based on the query
  results = query_embeddings(query, index, metadata, k)

  # Content Merge: Combine the retrieved content into a single string
  combined_content = combined_retrived_content(results)

  # Generation: Generate a response based on the query and combined content
  response = generate_response(query, combined_content, system_prompt)

  # Return the generated response
  return response

# %%
# Test the rag system
query1 = "How to make the best chocolate cake?"
response = rag_system(query1, index, metadata, system_prompt3)
get_gpt_response()
# Out:
# The query embedding is [-0.002604733919724822, -0.03968388959765434, -0.013297276571393013, 0.007617205381393433, -0.019327564164996147, 0.022370068356394768, 0.00810969714075327, -0.005398256704211235, -0.006457113660871983, 0.037473149597644806, -0.0003669747384265065, 0.007113769184798002, -0.05170068517327309, -0.007600788958370686, 0.0003343129646964371, -0.04031865671277046, 0.021166199818253517, -0.004692351911216974, -0.004487146623432636, -0.015858232975006104, 0.015004580840468407, -0.02479969523847103, -0.011732247658073902, 0.03399287164211273, 0.0030698650516569614, 0.006758080795407295, 0.022610843181610107, -0.0006980386096984148, -0.036904048174619675, 0.05677882209420204, 0.04460880532860756, 0.0018906210316345096, -0.016208449378609657, -0.014720030128955841, -0.02911173366010189, 0.016919827088713646, -0.004768961574882269, -0.001930293976329267, 0.03475897014141083, 0.014402646571397781, -0.005751208867877722, 5.8526144130155444e-05, 0.002621150342747569, 0.01079104095697403, -0.011283532716333866, 0.008624076843261719, 0.019283786416053772, 0.04797963798046112, 0.021209977567195892, -0.01790481060743332, -0.0007428416865877807, 0.007234156131744385, 0.04732298105955124, 0.0073271822184324265, -0.012651565484702587, 0.03615983575582504, 0.008613132871687412, -0.04885517805814743, 0.03432120010256767, 0.03716670721769333, 0.015059302560985088, -0.01351616159081459, -0.0006426332984119654, 0.009461313486099243, 0.0009364183060824871, 0.005959149915724993, -0.025806566700339317, 0.027973530814051628, -0.008930516429245472, 0.021954186260700226, 0.01451208908110857, 0.0002156361297238618, -0.024580808356404305, 0.0016936243046075106, -0.005225884262472391, 0.019809111952781677, 0.0052641890943050385, -0.008416136726737022, 0.019973276183009148, 0.00867332611232996, -0.01647111214697361, -0.037692032754421234, -0.013078391551971436, 0.010769152082502842, 0.04920539632439613, 0.01902112551033497, -0.0021478112321347, -0.023464495316147804, -9.473625686950982e-05, 0.015869177877902985, -0.01870374195277691, -0.022282514721155167, 0.046097226440906525, 0.0011067383456975222, 0.013494273647665977, 0.0030425044242292643, 0.029286840930581093, -0.005784041713923216, -0.05270756036043167, 0.00450082728639245, -0.014304148964583874, -0.014730975031852722, -0.016055230051279068, -0.05467752739787102, -0.008525579236447811, -0.013439551927149296, -0.0031492109410464764, -0.007929116487503052, 0.006900356151163578, -0.11408296972513199, -0.01598956435918808, 0.02118808776140213, -0.021636802703142166, 0.012640620581805706, -0.010484601370990276, -0.05117536336183548, -0.02622244879603386, -0.00867332611232996, 0.018375413492321968, -0.0415881909430027, 0.013822601176798344, 0.03375209867954254, 0.0380641371011734, 0.02814863808453083, -0.0045692287385463715, -0.019382284954190254, 0.0033516797702759504, -0.014763807877898216, 0.023223720490932465, -0.00800025463104248, -0.019634002819657326, -0.023486383259296417, -0.0017798104090616107, 0.0038031304720789194, 0.007409264333546162, -0.011097480542957783, 0.04077831655740738, 0.020750317722558975, 0.04517790675163269, 0.03272333741188049, 0.02615678310394287, -0.015321964398026466, -0.017882920801639557, 0.003822282887995243, -0.03414609283208847, 0.003715576371178031, 0.0008338158368133008, -0.013986765407025814, 0.03079714998602867, 0.05091270059347153, -0.023770933970808983, -0.01846296712756157, -0.03432120010256767, 0.024405701085925102, 0.02342071756720543, 0.011524306610226631, -0.006369559559971094, -0.036838382482528687, -0.03872079402208328, 0.01458869967609644, 0.009215067140758038, -0.030578263103961945, 0.03815169259905815, -0.011179561726748943, -0.0027524814940989017, 0.009844362735748291, 0.003970030695199966, 0.012651565484702587, -0.0707874745130539, 0.03232934698462486, 0.010905955918133259, 0.022917281836271286, -0.022742172703146935, -0.02368338033556938, -0.043054722249507904, 0.0025814773980528116, 0.037298038601875305, -0.02871773950755596, 0.0491178 ...
#
# The query vector is [[-0.00260473 -0.03968389 -0.01329728 ...  0.01214813 -0.01021099
#   -0.00113547]]
#
# The stored indices are [29, 25, 31, 23, 69]
#
# The stored distances are [1.212904930114746, 1.2393382787704468, 1.3063180446624756, 1.3158801794052124, 1.3221302032470703]
# To make the best chocolate cake, you can follow this structured recipe for a classic chocolate cake:
#
# ### Recipe Title
# Chocolate Cake
#
# ### Ingredients
# - 1½ Cups of Molasses
# - 1½ Cups of Sugar
# - ½ Cup of Milk
# - 2 Squares of Chocolate
# - 1 Small Teaspoon of Butter
# - 1½ Cups of Flour
# - 2 Teaspoons of Baking Powder
# - ½ Teaspoon of Salt
# - 1 Cup of Boiling Water
#
# ### Step-by-Step Instructions
# 1. Preheat your oven to 350°F (175°C).
# 2. In a saucepan, melt the chocolate with the butter and milk over low heat.
# 3. In a large mixing bowl, combine the molasses, sugar, and flour.
# 4. Add the melted chocolate mixture to the dry ingredients and mix well.
# 5. Stir in the baking powder and salt.
# 6. Gradually add the boiling water to the batter, mixing until smooth.
# 7. Pour the batter into a greased cake pan.
# 8. Bake for about 30-35 minutes or until a toothpick inserted in the center comes out clean.
# 9. Allow the cake to cool before serving.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Cake
#
# ### Relevant Tags/Metadata
# - Baking
# - Dessert
# - Chocolate Cake
# - Classic Recipe
#
# Feel free to ask if you need more details or variations!

# %%
# Test with a different query
query2 = "I want something vegan"
response = rag_system(query2, index, metadata, system_prompt3)
get_gpt_response()
# Out:
# The query embedding is [-0.034548308700323105, -0.026619188487529755, -0.017104245722293854, 0.03446335345506668, -0.01730247214436531, -0.008516724221408367, 5.26128314959351e-06, -0.018930774182081223, -0.033670444041490555, 0.023518336936831474, 0.003238904057070613, -0.012955616228282452, 0.0179679524153471, -0.007178685627877712, 0.036842089146375656, -0.008821146562695503, 0.009663615375757217, -0.01138395071029663, 0.007461868692189455, -0.018406886607408524, -0.023546654731035233, 0.00599993672221899, 0.037436775863170624, -0.0069061219692230225, 0.007702574133872986, 0.008198143914341927, -0.022074105218052864, -0.012240579351782799, 0.002099093049764633, 0.01846352219581604, 0.010208742693066597, 0.024481158703565598, -0.0050618937239050865, 0.05527729541063309, -0.013698970898985863, -0.003830048255622387, 0.038739416748285294, -0.0019114842871204019, 0.015617535449564457, 0.026930689811706543, -0.04777294769883156, 0.022003307938575745, -0.024226294830441475, 0.0013654723297804594, -0.022357286885380745, -0.0058548059314489365, 0.0030389060266315937, 0.005614100489765406, 0.0317164808511734, -0.040466830134391785, 0.01402463112026453, -0.0028884653002023697, 0.037125274538993835, -0.018194498494267464, 0.011907839216291904, 0.03854118660092354, 0.011766248382627964, -0.02956429123878479, 0.040013737976551056, -0.018690068274736404, -0.033104076981544495, -0.004516766872256994, 0.009635296650230885, -0.018505999818444252, -0.002750413492321968, 0.0023327188100665808, 0.013521981425583363, 0.029054561629891396, -0.0010026443051174283, 0.02012014202773571, -0.008219382725656033, -0.003454830963164568, -0.0039468612521886826, -0.019298912957310677, 0.03893764317035675, -0.03678545355796814, -0.004902603570371866, -0.013217560015618801, -0.018137862905859947, 0.029026243835687637, -0.01652372069656849, -0.03262266516685486, 0.01132731419056654, 0.007872483693063259, 0.03214125335216522, 0.0099538778886199, 0.014966214075684547, -0.06620815396308899, -0.03817304968833923, 0.008991056121885777, 0.02381567843258381, 0.023277631029486656, 0.0162122193723917, -0.026930689811706543, 0.020842259749770164, -0.01772724650800228, 0.013373310677707195, 0.0018884757300838828, -0.012764467857778072, 0.0014247638173401356, -0.016792744398117065, -0.02160685323178768, -0.043893344700336456, -0.03477485477924347, 0.01564585417509079, 0.01446356438100338, -0.006003476679325104, 0.06705769896507263, -0.048820726573467255, -0.09594235569238663, -0.008672474883496761, 0.02241392433643341, -0.026307689025998116, -0.006127369124442339, -0.005015876609832048, 0.016325492411851883, -0.05094459652900696, -0.00444951094686985, -0.0034742997959256172, -0.019440503790974617, 0.008141507394611835, -0.0009221141808666289, 0.005182246211916208, 0.0006026485352776945, 0.0035716439597308636, 0.004768091253936291, -0.032650984823703766, -0.021904194727540016, 0.015150283463299274, -0.023093562573194504, -0.008941498585045338, 0.01635381020605564, -0.011306076310575008, 0.034095216542482376, 0.04471457377076149, 0.005957459565252066, 0.024325408041477203, 0.05575870722532272, 0.013429947197437286, 0.016651151701807976, -0.004591102246195078, -0.022612152621150017, 0.0015141434269025922, -0.001108837896026671, -0.023320108652114868, -0.025189116597175598, 0.0012168013490736485, -0.01663699373602867, 0.02241392433643341, 0.00261236191727221, 0.03293416649103165, -0.03177311643958092, -0.013274196535348892, -0.01581576280295849, 0.022881176322698593, 0.03474653884768486, 0.019808640703558922, -0.01801043003797531, -0.005953919608145952, -0.007900801487267017, 0.013507822528481483, 0.00644948985427618, -0.01284234318882227, 0.007454788777977228, -0.0025274071376770735, -0.044799529016017914, -0.029479335993528366, -0.020346688106656075, -0.023192675784230232, 0.029507653787732124, -0.014952055178582668, -0.010109628550708294, 0.02494841068983078, 0.012785706669092178, -0.0034689900930970907, 0.03644563630223274, 0.04729153960943222, -0.0012380400439724326, 0 ...
#
# The query vector is [[-0.03454831 -0.02661919 -0.01710425 ... -0.00479287 -0.00443181
#    0.00334864]]
#
# The stored indices are [11, 99, 7, 93, 3]
#
# The stored distances are [1.4484549760818481, 1.46428382396698, 1.4792256355285645, 1.4798717498779297, 1.4813312292099]
# It seems that the recipes provided do not contain any vegan options, as they include ingredients like butter, milk, eggs, and other animal products. If you're looking for vegan recipes, I can help you create or suggest some based on common vegan ingredients.
#
# Here are a few simple vegan sauce ideas:
#
# 1. **Vegan Chocolate Sauce**:
#    - Ingredients: 1 cup of coconut milk, 1/2 cup of cocoa powder, 1/2 cup of maple syrup, 1 teaspoon of vanilla extract.
#    - Instructions: In a saucepan, combine all ingredients over medium heat. Stir until smooth and heated through.
#
# 2. **Vegan Creamy Mustard Sauce**:
#    - Ingredients: 1/2 cup of cashew cream (soaked cashews blended with water), 1 tablespoon of mustard, 1 tablespoon of apple cider vinegar, salt to taste.
#    - Instructions: Mix all ingredients in a bowl until well combined.
#
# 3. **Vegan Cranberry Sauce**:
#    - Ingredients: 1 cup of fresh cranberries, 1/2 cup of orange juice, 1/4 cup of maple syrup.
#    - Instructions: In a saucepan, combine all ingredients and cook over medium heat until cranberries burst and sauce thickens.
#
# If you have specific ingredients or types of sauces in mind, let me know, and I can help you further!
